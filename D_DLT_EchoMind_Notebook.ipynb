# %% [markdown]
# # EchoMind: A Window to Mental Health

# %% [markdown]
# ## DAIC-WOZ Dataset - Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Setup and Folder Structure

# %%
import os
import pandas as pd
import librosa
import matplotlib.pyplot as plt

parent_dir = './DAICWOZ_MAIN'
sessions = [f for f in os.listdir(parent_dir) if os.path.isdir(os.path.join(parent_dir, f)) and f.endswith('_P')]
print("Total sessions detected:", len(sessions))
# Out:
# Total sessions detected: 189

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="librosa.core.intervals")

# %% [markdown]
# ### EDA Extraction for each audio file

# %% [markdown]
# ##### extract:
# - Audio duration and sample rate
# - Transcript word count and number of participant responses

# %%
import re

def parse_daicwoz_transcript(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    # Always expect 4 columns: start_time, stop_time, speaker, value
    header = ['start_time', 'stop_time', 'speaker', 'value']
    rows = []
    for line in lines[1:]:
        # Try to split by two or more spaces, then by tab as fallback
        line_split = re.split(r'\s{2,}|\t', line.strip())
        if len(line_split) == 4:  # Proper line
            rows.append(line_split)
        else:  # Fallback: split by any whitespace
            line_split_alt = re.split(r'\s+', line.strip())
            if len(line_split_alt) >= 4:
                rows.append(line_split_alt[:4])
    df = pd.DataFrame(rows, columns=header)
    return df

# %%
import os

parent_dir = './DAICWOZ_MAIN'
session = '300_P'
session_path = os.path.join(parent_dir, session)
transcript_file = [f for f in os.listdir(session_path) if 'TRANSCRIPT' in f and f.endswith('.csv')][0]

df_t = parse_daicwoz_transcript(os.path.join(session_path, transcript_file))
print(f"Session: {session}")
print(df_t.head(10))  # Visualize first 10 rows

# Extract participant utterances
utterances = df_t[df_t['speaker'].str.lower().str.strip() == 'participant']['value'].dropna().astype(str).tolist()
print(f"Utterances preview:", utterances[:5])
print(f"Total participant utterances:", len(utterances))
# Out:
# Session: 300_P
#   start_time stop_time      speaker  \
# 0     36.588    39.668        Ellie
# 1     39.888    43.378        Ellie
# 2     43.728    48.498        Ellie
# 3     49.188    52.388        Ellie
# 4     52.658    58.958        Ellie
# 5     60.028    61.378        Ellie
# 6     62.328    63.178  Participant
# 7     63.798    64.738        Ellie
# 8     65.858    67.528        Ellie
# 9     68.978    70.288  Participant
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  think of me as a friend i don't judge i can't ...
# 3  i'm here to learn about people and would love ...
# 4  i'll ask a few questions to get us started and...
# 5                            how are you doing today
# 6                                               good
# 7                                        that's good
# 8                      where are you from originally
# 9                                    atlanta georgia
# Utterances preview: ['good', 'atlanta georgia', 'um my parents are from here um', 'i love it', 'i like the weather']
# Total participant utterances: 87

# %%
def batch_eda(parent_dir):
    def parse_daicwoz_transcript(filepath):
        with open(filepath, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        header = ['start_time', 'stop_time', 'speaker', 'value']
        rows = []
        for line in lines[1:]:
            # Split by tabs, then try 2+ spaces as fallback
            line_split = re.split(r'\t| {2,}', line.strip())
            if len(line_split) == 4:
                rows.append(line_split)
            else:
                # Fallback: split by any whitespace and use first 4 items
                line_split_alt = re.split(r'\s+', line.strip())
                if len(line_split_alt) >= 4:
                    rows.append(line_split_alt[:4])
        df = pd.DataFrame(rows, columns=header)
        return df

    session_list = [f for f in os.listdir(parent_dir) if os.path.isdir(os.path.join(parent_dir, f)) and f.endswith('_P')]
    results = []
    text_data = {}
    for session in session_list:
        session_path = os.path.join(parent_dir, session)
        files = os.listdir(session_path)
        transcript_files = [f for f in files if 'TRANSCRIPT' in f and f.endswith('.csv')]
        audio_files = [f for f in files if f.endswith('_AUDIO.wav')]
        if not transcript_files:
            print(f"Missing transcript for {session}")
            continue
        try:
            df = parse_daicwoz_transcript(os.path.join(session_path, transcript_files[0]))
            print(f"Session: {session}")
            print(df.head())  # Visualize parsing
            # Only keep participant utterances
            utterances = df[df['speaker'].str.lower().str.strip() == 'participant']['value'].dropna().astype(str).tolist()
            text_data[session] = ' '.join(utterances)
            print(f"Transcript preview: {text_data[session][:200]}")
            num_utterances = len(utterances)
            word_count = len(text_data[session].split())
        except Exception as e:
            print(f"Transcript parse error for {session}: {e}")
            num_utterances, word_count = 0, 0
            text_data[session] = ""
        # Audio stats
        duration = None
        sample_rate = None
        if audio_files:
            try:
                import librosa
                audio_path = os.path.join(session_path, audio_files[0])
                y, sr = librosa.load(audio_path, sr=None)
                duration = librosa.get_duration(y=y, sr=sr)
                sample_rate = sr
            except Exception as e:
                print(f"Audio error for {session}: {e}")
        results.append({
            'session': session,
            'audio_duration': duration,
            'sample_rate': sample_rate,
            'transcript_word_count': word_count,
            'num_responses': num_utterances
        })
    return pd.DataFrame(results), text_data

# %%
# To call it:
parent_dir = './DAICWOZ_MAIN'
total_df, text_data = batch_eda(parent_dir)
print(total_df)
print(text_data['300_P'][:500])  # Example check
# Out:
# Session: 300_P
#   start_time stop_time speaker  \
# 0     36.588    39.668   Ellie
# 1     39.888    43.378   Ellie
# 2     43.728    48.498   Ellie
# 3     49.188    52.388   Ellie
# 4     52.658    58.958   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  think of me as a friend i don't judge i can't ...
# 3  i'm here to learn about people and would love ...
# 4  i'll ask a few questions to get us started and...
# Transcript preview: good atlanta georgia um my parents are from here um i love it i like the weather i like the opportunities um yes um it took a minute somewhat easy congestion that's it um i took up business and admini
# Session: 301_P
#   start_time stop_time      speaker  \
# 0     29.428    35.888        Ellie
# 1     32.738    33.068  Participant
# 2     36.598    40.948        Ellie
# 3     42.088    42.518  Participant
# 4     42.358    51.738        Ellie
#
#                                                value
# 0  hi i'm ellie thanks for coming in today i was ...
# 1                                          thank you
# 2  think of me as a friend i don't judge i can't ...
# 3                                              mmm k
# 4  i'm here to learn about people and would love ...
# Transcript preview: thank you mmm k i'm doing good thank you i'm from los angeles oh great i live in west los angeles the west side it's alright i xxx no i live alone so i love it i'm from here so i grew up here it's nat
# Session: 302_P
#   start_time stop_time speaker  \
# 0      35.18     37.99   Ellie
# 1      38.59     41.72   Ellie
# 2      42.46     46.77   Ellie
# 3      47.67     57.06   Ellie
# 4      58.43      59.4   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  think of me as a friend i don't judge i can't ...
# 3  i'm here to learn about people and would love ...
# 4                            how are you doing today
# Transcript preview: i'm fine how about yourself i'm from los angeles california what part okay um all my family's here friends a mixture of people and a lot of things to do early childhood education no not right now but
# Session: 303_P
#   start_time stop_time      speaker  \
# 0     26.276    48.696        Ellie
# 1     49.256    50.406        Ellie
# 2     50.686    51.836  Participant
# 3     52.576    54.136        Ellie
# 4     54.816    56.236        Ellie
#
#                                                value
# 0  hi i'm ellie thanks for coming in today i was ...
# 1                            how are you doing today
# 2                            okay how 'bout yourself
# 3                                   i'm great thanks
# 4                      where are you from originally
# Transcript preview: okay how 'bout yourself here in california yeah oh well that it's big and broad there's a lot to do a lot of um um job opportunities than other states um pretty much that it's big and there's a lot yo
# Session: 304_P
#   start_time stop_time      speaker  \
# 0      34.01     45.81        Ellie
# 1      46.96     56.97        Ellie
# 2       57.9     59.05        Ellie
# 3      59.82     62.31  Participant
# 4      62.32     63.24        Ellie
#
#                                                value
# 0  hi i'm ellie thanks for coming in today i was ...
# 1  i''m here to learn about people and would love...
# 2                            how are you doing today
# 3                                  i'm doing good um
# 4                                        that's good
# Transcript preview: i'm doing good um from los angeles california um the cool weather the beaches the people the schools um child development yes to be a teacher for special education it's not hard 'cause i love to work
# Session: 305_P
#   start_time stop_time      speaker  \
# 0     28.655    40.645        Ellie
# 1     41.355    50.955        Ellie
# 2     51.625    52.785        Ellie
# 3     53.245    54.445  Participant
# 4     55.045    55.835        Ellie
#
#                                                value
# 0  hi i'm ellie thanks for coming in today i was ...
# 1  i'm here to learn about people and would love ...
# 2                            how are you doing today
# 3                                  i'm doing alright
# 4                                        that's good
# Transcript preview: i'm doing alright uh originally i'm from california uh born in glendale i'm not too happy with it uh just unemployed at the moment but uh actively seeking uh uh doing what i'm supposed to be doing uh
# Session: 306_P
#   start_time stop_time speaker  \
# 0     32.613    35.553   Ellie
# 1     35.983    39.273   Ellie
# 2     39.813    41.123   Ellie
# 3     41.463    44.373   Ellie
# 4     46.213    51.893   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2                            think of me as a friend
# 3               i don't judge i can't i'm a computer
# 4  i'm here to learn about people and would love ...
# Transcript preview: fine uh colorado mhm uh career career possibilities uh paralegal uh for further education for the weather for a friend [laughter] not often at all now every few years oh the weather uh the beach sunse
# Session: 307_P
#   start_time stop_time      speaker  \
# 0     32.283    44.021        Ellie
# 1      44.68    54.475        Ellie
# 2      54.58     55.39  Participant
# 3      55.15     56.74        Ellie
# 4      57.67     59.52  Participant
#
#                                                value
# 0  hi i'm ellie thanks for coming in today i was ...
# 1  i'm here to learn about people and would love ...
# 2                                         <laughter>
# 3                      where are you from originally
# 4                                          um moscow
# Transcript preview: <laughter> um moscow um my family moved to the u_s and then i moved down here eventually for college  uh it took a long time to i've been living here for about a year since i graduated so there's been
# Session: 308_P
#   start_time stop_time speaker  \
# 0     33.736    36.456   Ellie
# 1     37.076    40.306   Ellie
# 2     40.976    45.326   Ellie
# 3     46.306    55.786   Ellie
# 4     56.766    57.996   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  think of me as a friend i don't judge i can't ...
# 3  i'm here to learn about people and would love ...
# 4                      where are you from originally
# Transcript preview: los angeles california yes um the southern california lifestyle the beaches the um active lifestyle the traffic the pretentious people um my teachers um i don't know certain teachers um got uh spiritu
# Session: 309_P
#   start_time stop_time      speaker  \
# 0     53.403    56.323        Ellie
# 1      57.03     60.43        Ellie
# 2     61.317    65.417        Ellie
# 3     65.696    67.746        Ellie
# 4     67.623    70.843  Participant
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3         i'll ask a few questions to get us started
# 4                                         <laughter>
# Transcript preview: <laughter> <laughter> yeah <laughter> <laughter> i'm doing good <laughter> uh arizona uh because of acting and other stuff like that entertain <entertai> enterainment industry no not at the moment at
# Session: 310_P
#   start_time stop_time speaker  \
# 0      34.18     37.05   Ellie
# 1     37.875    41.175   Ellie
# 2     42.097    46.017   Ellie
# 3     46.492    48.552   Ellie
# 4     49.137    53.762   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3         i'll ask a few questions to get us started
# 4  and please feel free to tell me anything your ...
# Transcript preview: yes it's okay <laughter> fine <laughter> i live in hollywood uh seattle <laughter> uh it's kind of a vague question um <laughter> just needed a change of scenery uh i like traveling by train it's not
# Session: 311_P
#   start_time stop_time speaker  \
# 0       35.2     38.13   Ellie
# 1      38.89      42.2   Ellie
# 2      43.12     49.51   Ellie
# 3      50.22     54.84   Ellie
# 4      55.41      56.6   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes okay uh when'd i move to l_a um moved here a long time ago to live to go to work um well arizona and colorado i don't uh money don't have the money for it l_a's much nicer um <sigh> the people the
# Session: 312_P
#   start_time stop_time speaker  \
# 0      46.64     49.53   Ellie
# 1      50.37      53.7   Ellie
# 2      54.62     60.98   Ellie
# 3      61.69      66.3   Ellie
# 4       66.9     68.12   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes fine how about you here yes the weather weather mainly yeah the main <ma> the weather sorry not the people well some of the people stuff like that some people okay i'm cutting you off not as much
# Session: 313_P
#   start_time stop_time speaker  \
# 0      51.74     54.62   Ellie
# 1     55.395    58.745   Ellie
# 2     59.635    65.965   Ellie
# 3     66.692    71.292   Ellie
# 4     71.992    73.132   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: sure uh okay i guess not bad not good so so denver colorado uh to pursue job opportunities uh about two years ago uh once or twice a year uh i really like the sunshine um all the opportunities all the
# Session: 314_P
#   start_time stop_time speaker  \
# 0      10.53     11.43   Ellie
# 1      36.82     40.13   Ellie
# 2       40.4     43.99   Ellie
# 3       44.8     48.98   Ellie
# 4     49.085    56.595   Ellie
#
#                                                value
# 0                                             [sync]
# 1            hi i'm ellie thanks for coming in today
# 2  i was created to talk to people in a safe and ...
# 3  i'm not a therapist but i'm here to learn abou...
# 4  i'll ask a few questions to get us started and...
# Transcript preview: yes quite well feel good los angeles california here mhm one of the few um native born los angelinos i uh home school my ten year old son and uh i'm a home maker i have five children and married twent
# Session: 315_P
#   start_time stop_time      speaker  \
# 0     55.305    58.305        Ellie
# 1      56.86     57.14  Participant
# 2      58.98     62.39        Ellie
# 3      63.24    69.605        Ellie
# 4      70.34     75.01        Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1                                            alright
# 2  i was created to talk to people in a safe and ...
# 3  i'm not a therapist but i'm here to learn abou...
# 4  and please feel free to tell me anything your ...
# Transcript preview: alright yes okay and you inglewood california yes no uh it's okay um you mean my girlfriend and my daughter yes they're they're okay it's okay it's cool yes i do um well i'm a football recruiter so i
# Session: 316_P
#   start_time stop_time speaker  \
# 0      38.78      41.7   Ellie
# 1      42.45     45.85   Ellie
# 2      46.72     53.04   Ellie
# 3      53.83     58.35   Ellie
# 4      59.07     60.22   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm fine new york uh for business now um i do hospitality i'm in between jobs when um <sneeze> excuse me um third lemmi see twenty six years ago mm once a year the sun the beach palm trees <laught
# Session: 317_P
#   start_time stop_time      speaker  \
# 0      32.56    39.587        Ellie
# 1     40.485     46.73        Ellie
# 2      47.49     53.84        Ellie
# 3      54.52     55.02  Participant
# 4      56.09     56.52        Ellie
#
#                                                value
# 0  hi i'm ellie thanks for coming in today i was ...
# 1  i'm not a therapist but i'm here to learn abou...
# 2  and please feel free to tell me anything your ...
# 3                                                yes
# 4                                               okay
# Transcript preview: yes uh i'm okay a little sleepy right now i'm from new york um i wanted a change of environment and i wanted to start over somewhere um about two years ago um it took uh a bit of an a bit of adjustmen
# Session: 318_P
#   start_time stop_time speaker  \
# 0      12.43     15.41   Ellie
# 1      16.15     19.56   Ellie
# 2      20.38     26.86   Ellie
# 3      27.48     32.12   Ellie
# 4       32.7     33.93   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm alright los angeles california yep um the lights big city it's always something going on the traffic and that's it uh business administration and business management uh not that i'm doing some
# Session: 319_P
#   start_time stop_time speaker  \
# 0      48.58     51.65   Ellie
# 1      52.31     55.79   Ellie
# 2      56.48     63.05   Ellie
# 3      63.71     68.35   Ellie
# 4      68.94     70.12   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: sure mm okay los angeles um well <laughter> that's a good question um i like the familiarity with everything i know where everything is in the city mm that's all i can say right now so spread out so h
# Session: 320_P
#   start_time stop_time      speaker  \
# 0       6.02      7.05  Participant
# 1      60.84     63.75        Ellie
# 2     64.495    67.955        Ellie
# 3      68.72     75.12        Ellie
# 4       75.8     80.49        Ellie
#
#                                                value
# 0                                          [syncing]
# 1            hi i'm ellie thanks for coming in today
# 2  i was created to talk to people in a safe and ...
# 3  i'm not a therapist but i'm here to learn abou...
# 4  and please feel free to tell me anything your ...
# Transcript preview: [syncing] yes i'm a little nervous mm this is different california yes i like the beach um the weather mm mm so many people [laughter] yeah what do you mean what do i do now i don't know right now um
# Session: 321_P
#   start_time stop_time speaker  \
# 0     34.205    37.145   Ellie
# 1     37.865    41.265   Ellie
# 2     42.095    46.175   Ellie
# 3     46.595    48.615   Ellie
# 4       49.2    53.915   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3         i'll ask a few questions to get us started
# 4  and please feel free to tell me anything your ...
# Transcript preview: yeah i'm okay um chicago illinois mhm uh my husband's work was here in eighty four it was not easy for me it took about three years um just the move i moved away from my family so i was uncomfortable
# Session: 322_P
#   start_time stop_time speaker  \
# 0     39.185    42.185   Ellie
# 1     42.895    46.315   Ellie
# 2      47.18     51.21   Ellie
# 3     51.602    53.652   Ellie
# 4     54.275    58.885   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3         i'll ask a few questions to get us started
# 4  and please feel free to tell me anything your ...
# Transcript preview: yes fine thank you i'm originally from india yeah i'm sorry why <wh> why do i miss sorry why do i miss l_a oh about twenty years ago oh once every three four years um i mean the first <f> the first si
# Session: 323_P
#   start_time stop_time speaker  \
# 0      51.57     54.49   Ellie
# 1      55.22     58.63   Ellie
# 2      59.52     65.92   Ellie
# 3      66.59      71.2   Ellie
# 4      71.82     72.95   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: sure good chicago it's cold in chicago hmm oh i think in ninety nineteen eighty nine actually oh very simple very easy oh weather of course and i'm so easily located to san diego palm springs las vega
# Session: 324_P
#   start_time stop_time speaker  \
# 0      54.64     57.96   Ellie
# 1     58.405    62.025   Ellie
# 2      62.72     69.15   Ellie
# 3      69.74     74.46   Ellie
# 4     75.115    76.335   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything you a...
# 4                             are you okay with this
# Transcript preview: yeah yes fine how are you uh born and raise right here on the west side venice beach [laughter] everything the beach the weather uh the beach the weather um everything the girls uh nothing nothing tra
# Session: 325_P
#   start_time stop_time speaker  \
# 0       27.6     30.56   Ellie
# 1      31.41     34.68   Ellie
# 2      35.59     42.08   Ellie
# 3      42.67     47.38   Ellie
# 4       47.9     49.11   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything you'r...
# 4                             are you okay with this
# Transcript preview: yes um i'm fine this is a little bit strange you know talking to a virtual human um i was born i was born in l_a i was raised out in the suburbs um i've lived all over los angeles i've lived in the va
# Session: 326_P
#   start_time stop_time speaker  \
# 0      60.85     63.91   Ellie
# 1      64.54     67.91   Ellie
# 2      68.83     75.29   Ellie
# 3      75.88     80.55   Ellie
# 4      81.17     82.33   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm fine um ohio mmm <laughter> bigger city more opportunity um bigger city big city not often um i don't know uh there's phones i can call um let's see the water the ocean um the big city there's
# Session: 327_P
#   start_time stop_time speaker  \
# 0      36.22    39.555   Ellie
# 1     39.945    43.555   Ellie
# 2     44.195     50.65   Ellie
# 3       51.3     56.02   Ellie
# 4      56.56     57.84   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes fine thank you montreal canada i moved here with my mom when i was in high school yes oh it's very cold there in the winter and our summers are very short it was very easy i accustom pretty quick
# Session: 328_P
#   start_time stop_time speaker  \
# 0      29.68     32.71   Ellie
# 1      33.39     36.73   Ellie
# 2      37.63     44.11   Ellie
# 3      44.76     49.37   Ellie
# 4      49.99     51.11   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes <laughter> fine how are you uh watts california but now i live in west l_a <laughter> yes i love uh the sunshine i love the palm trees i love that um you're thirty minutes away from everything it'
# Session: 329_P
#   start_time stop_time speaker  \
# 0      26.04     29.38   Ellie
# 1      29.93     33.45   Ellie
# 2      34.11     40.73   Ellie
# 3      41.23        46   Ellie
# 4      46.55     47.87   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes pretty well from new york uh to go to college well to san diego to go to college and then later to l_a aerospace engineering um it was i was really good at math and science and i had a interest in
# Session: 330_P
#   start_time stop_time      speaker  \
# 0      33.07     33.83  Participant
# 1      33.39     36.36        Ellie
# 2       37.1     40.53        Ellie
# 3      41.34     47.84        Ellie
# 4      48.47     53.01        Ellie
#
#                                                value
# 0                                         <laughter>
# 1            hi i'm ellie thanks for coming in today
# 2  i was created to talk to people in a safe and ...
# 3  i'm not a therapist but i'm here to learn abou...
# 4  and please feel free to tell me anything your ...
# Transcript preview: <laughter> yes i'm okay with this very good l_a it's sunny and uh it's near the ocean <sigh> uh the traffic can make it difficult to drive around between different places and there's a lack of uh uh o
# Session: 331_P
#   start_time stop_time speaker  \
# 0      27.88     30.89   Ellie
# 1      31.57     34.93   Ellie
# 2      35.89     42.23   Ellie
# 3      42.96     47.61   Ellie
# 4       48.2     49.33   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes okay connecticut um to be an actor <laughter> well i moved to san francisco in ninety four and then i moved to atlanta in ninety six and then i moved out here to be an actor and i became a realtor
# Session: 332_P
#   start_time stop_time      speaker  \
# 0      86.85      93.9        Ellie
# 1      94.78    101.33        Ellie
# 2     101.87    106.53        Ellie
# 3     107.11    108.27        Ellie
# 4      108.5    108.94  Participant
#
#                                                value
# 0  hi i'm ellie thanks for coming in today i was ...
# 1  i'm not a therapist but i'm here to learn abou...
# 2  and please feel free to tell me anything your ...
# 3                             are you okay with this
# 4                                                yes
# Transcript preview: yes fine just tired california from hollywood uh not too much <laughter> there's not too many things i like about it uh the people um it's not clean too much crime too many drugs uh makeup and hair it
# Session: 333_P
#   start_time stop_time      speaker  \
# 0      26.94     34.09        Ellie
# 1         35     41.42        Ellie
# 2      42.08     46.69        Ellie
# 3      47.29     48.45        Ellie
# 4       49.1     49.44  Participant
#
#                                                value
# 0  hi i'm ellie thanks for coming in today i was ...
# 1  i'm not a therapist but i'm here to learn abou...
# 2  and please feel free to tell me anything your ...
# 3                             are you okay with this
# 4                                                yes
# Transcript preview: yes very well new york just turn the volume up a little bit <laughter> uh for a change yeah it's good i wanted <wa> i wanted to i wanted to see what los angeles was about um probably took a year or tw
# Session: 334_P
#   start_time stop_time      speaker  \
# 0      48.28      51.3        Ellie
# 1      51.99     55.36        Ellie
# 2      56.25     62.83        Ellie
# 3       60.5     60.97  Participant
# 4      63.38        68        Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 
Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm doing pretty good <laughter> i'm from oklahoma mhm yup oklahoma city uh the weather is great i love being near the ocean and the palm trees and uh mountains i just love it here <laughter> um i
# Session: 353_P
#   start_time stop_time speaker  \
# 0      18.77     21.79   Ellie
# 1      22.41     25.84   Ellie
# 2      26.71     33.24   Ellie
# 3      33.81     38.49   Ellie
# 4      38.99     40.17   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm okay um pennsylvania mhm um well i was in boston for a couple years and then i moved here about three and a half years ago but um i just wasn't satisfied with the quality of my life um maybe o
# Session: 354_P
#   start_time stop_time speaker  \
# 0      17.27     20.22   Ellie
# 1      20.87     24.31   Ellie
# 2      25.13     31.67   Ellie
# 3       32.3     36.89   Ellie
# 4      37.47     38.91   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm alright with this doing pretty good little bit tired i'm from los angeles the weather and the sports can't find any jobs right now i know um not really i studied um architecture and chicano st
# Session: 355_P
#   start_time stop_time speaker  \
# 0       17.7      20.7   Ellie
# 1      21.42     24.79   Ellie
# 2      25.65     32.14   Ellie
# 3      32.66      37.3   Ellie
# 4      37.98     39.17   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes alright i was born in uh los angeles california uh well the weather and uh the fact that uh people aren't so obtrusive like on the east coast uh just the uh the traffic and the the smoggy weather
# Session: 356_P
#   start_time stop_time speaker  \
# 0      35.44     38.44   Ellie
# 1      39.14     42.59   Ellie
# 2      43.37     49.94   Ellie
# 3      50.48     55.12   Ellie
# 4      55.71     56.91   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes okay from here from eh from alhambra uh the weather's really nice and everything's very familiar uh sometimes there's too much congestion on the roads too too much traffic i i studied art and phot
# Session: 357_P
#   start_time stop_time      speaker  \
# 0      20.88     21.19  Participant
# 1      21.71     24.64        Ellie
# 2      25.41     28.75        Ellie
# 3       29.6     36.17        Ellie
# 4       36.7     41.33        Ellie
#
#                                                value
# 0                                                 hi
# 1            hi i'm ellie thanks for coming in today
# 2  i was created to talk to people in a safe and ...
# 3  i'm not a therapist but i'm here to learn abou...
# 4  and please feel free to tell me anything your ...
# Transcript preview: hi sure i'm fine tired i had to bike it here so my back is sweaty i'm from l_a um the places there is to go there's always things to do here um drivers i'm trying to do audio engineering working with
# Session: 358_P
#   start_time stop_time speaker  \
# 0     30.938    33.964   Ellie
# 1     34.681    38.097   Ellie
# 2     38.929     45.38   Ellie
# 3     46.088     50.68   Ellie
# 4      51.28     52.37   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes fine tampa florida uh at that point i wanted to get into the entertainment industry um nineteen ninety it took a long time to get used to it it wasn't easy well the weather and that if you have a
# Session: 359_P
#   start_time stop_time speaker  \
# 0      32.12        35   Ellie
# 1       35.8     39.24   Ellie
# 2      40.05      46.4   Ellie
# 3      47.14     51.76   Ellie
# 4      52.39     53.55   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes <laughter> i uh didn't get much sleep last night and xxx and it's cold and i'm i'm just gonna get through the day didn't have haven't even haven't showered <laughter> in two days that's i need to
# Session: 360_P
#   start_time stop_time speaker  \
# 0      29.04     32.06   Ellie
# 1      32.84     36.15   Ellie
# 2      37.06      43.5   Ellie
# 3      44.11     48.76   Ellie
# 4      49.37     50.51   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm doing good and yourself inglewood the scenery the the places to eat um i just i i just love l_a the traffic the public transit that's about it yes getting to getting to new places and seeing n
# Session: 361_P
#   start_time stop_time speaker  \
# 0      20.67     23.69   Ellie
# 1      24.43     27.81   Ellie
# 2       28.6     35.19   Ellie
# 3      35.67     40.39   Ellie
# 4      41.03     42.18   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm doing great how about you i'm born in the u_s i was born in uh orlando florida um my parents my dad had a lot of friends in los angeles so uh we decided to move here um it was pretty different
# Session: 362_P
#   start_time stop_time speaker  \
# 0       8.96     11.93   Ellie
# 1      12.67     16.11   Ellie
# 2       16.9     23.37   Ellie
# 3      23.93     28.64   Ellie
# 4      29.16     30.47   Ellie
#
#                                                value
# ...
# 3                                                yes
# 4                                okay_confirm (okay)
# Transcript preview: <synch> yes i'm good how are you uh i was born in hawaii but i grew up in colorado yeah yeah about seven <s> uh seven to eight years ago um i try to go back once a year <ye> once or twice a year yeah
# Session: 475_P
#   start_time stop_time      speaker  \
# 0      15.86     16.66  Participant
# 1     36.493    58.033        Ellie
# 2     58.525    58.905  Participant
# 3     59.751    60.211        Ellie
# 4     61.454    63.724        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes good thank you el segundo right down the street the beach the smog i try to when i have time being away from home getting away i recently went to palm springs with my wife and my friends u
# Session: 476_P
#   start_time stop_time      speaker  \
# 0      19.02     19.86  Participant
# 1     31.552    53.092        Ellie
# 2      53.72     54.31  Participant
# 3     55.133    55.593        Ellie
# 4     56.791    59.061        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                       uh yeah sure
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> uh yeah sure <laughter> i'm alright uh i'm in a weird test study right now uh i'm from los angeles mhm <ss> all kinds of different things to do in this city uh well i don't know each each area
# Session: 477_P
#   start_time stop_time      speaker  \
# 0      11.54     12.35  Participant
# 1     32.789    54.329        Ellie
# 2     54.075    54.865  Participant
# 3     55.674    56.134        Ellie
# 4     57.244    59.514        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                         yes thanks
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes thanks i'm well thank you how are you i grew up in oklahoma mhm um i moved to l_a about five and a half years ago so i used to be on the west <we> on the east coast and then i decided i wa
# Session: 478_P
#   start_time stop_time      speaker  \
# 0       37.5     38.35  Participant
# 1     57.166    78.706        Ellie
# 2      78.91     79.21  Participant
# 3     80.873    81.333        Ellie
# 4     82.653    84.923        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes uh good thanks the east coast for work uh rarely i prefer it out here uh i it's um not as nice as the lifestyle out here i like the weather better and uh just a lot of things about living
# Session: 479_P
#   start_time stop_time      speaker  \
# 0     11.429    12.289  Participant
# 1     31.877    53.417        Ellie
# 2     54.272    54.682  Participant
# 3     55.828    56.288        Ellie
# 4     57.815    60.085        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes okay l_a uh the smog traffic tickets high rent uh everything um like um the cost of living the smog yeah <clears throat> not anymore uh don't have the time um the meeting new people the fo
# Session: 480_P
#   start_time stop_time      speaker               value
# 0      20.26     21.19  Participant             <synch>
# 1      57.23     57.68  Participant                 yes
# 2      62.29     63.35  Participant  i'm fine thank you
# 3      66.94     67.87  Participant       new york city
# 4     70.425    70.885  Participant                 yes
# Transcript preview: <synch> yes i'm fine thank you new york city yes uh seventy <s> nineteen seventy five <f> five <laughter> about <bout> once a year both urban uh big cities but uh east coast has a little bit maybe a l
# Session: 481_P
#   start_time stop_time      speaker  \
# 0      26.64     27.57  Participant
# 1     42.645    64.185        Ellie
# 2      64.67     65.15  Participant
# 3      65.68     66.09  Participant
# 4     66.042    66.502        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                
Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                               yeah
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yeah i'm doing already how are you doing northern illinois two and a half years ago haven't yet since i been here haven't had a chance to gonna go back later this year colder or warmer work ye
# Session: 491_P
#   start_time stop_time      speaker  \
# 0       52.8      53.7  Participant
# 1         66     87.54        Ellie
# 2      88.53     88.96  Participant
# 3     89.733    90.193        Ellie
# 4     91.412    93.682        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes huh overwhelmed i have a funeral to attend tomorrow i found out from my doctor i got some health issues it is hard honey i am just putting one foot in front of the other and just trying to
# Session: 492_P
#   start_time stop_time      speaker  \
# 0      10.77     11.65  Participant
# 1     32.152    53.692        Ellie
# 2      53.54     54.06  Participant
# 3     55.422    55.882        Ellie
# 4     56.845    59.115        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes doing pretty good thank you maryland yes eighty five yeah yeah it is a long time um not as often as i'd like um out of work so you know the money issue yeah um maryland uh is different it
#     session  audio_duration  sample_rate  transcript_word_count  num_responses
# 0     300_P           648.5        16000                    352             87
# 1     301_P           823.9        16000                   1475            104
# 2     302_P           758.8        16000                    614             97
# 3     303_P           985.3        16000                   1807            103
# 4     304_P           792.6        16000                    957            104
# ..      ...             ...          ...                    ...            ...
# 184   488_P           884.9        16000                   1413            138
# 185   489_P           704.7        16000                    491            117
# 186   490_P           691.3        16000                    592             97
# 187   491_P           881.7        16000                   1241            146
# 188   492_P           912.5        16000                   1259            220
#
# [189 rows x 5 columns]
# good atlanta georgia um my parents are from here um i love it i like the weather i like the opportunities um yes um it took a minute somewhat easy congestion that's it um i took up business and administration uh yeah i am here and there i'm on a break right now but i plan on going back in the uh next semester uh probably to open up my own business no um no specific reason i just don't travel a lot i'm pretty local once a year can you be a little bit more specific no answer i like reading books i

# %% [markdown]
# ## Descriptive Statistics

# %%
# Be sure to unpack both DataFrame and text dictionary
total_df, text_data = batch_eda(parent_dir)

print("\nSession summary table:")
display(total_df)

print("\nSummary statistics:\n", total_df.describe())

print("Sessions processed:", len(total_df))
print("Sessions with audio:", total_df['audio_duration'].notnull().sum())
print("Sessions with transcript:", (total_df['transcript_word_count'] > 0).sum())
print("Info:")
print(total_df.info())
# Out:
# Session: 300_P
#   start_time stop_time speaker  \
# 0     36.588    39.668   Ellie
# 1     39.888    43.378   Ellie
# 2     43.728    48.498   Ellie
# 3     49.188    52.388   Ellie
# 4     52.658    58.958   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  think of me as a friend i don't judge i can't ...
# 3  i'm here to learn about people and would love ...
# 4  i'll ask a few questions to get us started and...
# Transcript preview: good atlanta georgia um my parents are from here um i love it i like the weather i like the opportunities um yes um it took a minute somewhat easy congestion that's it um i took up business and admini
# Session: 301_P
#   start_time stop_time      speaker  \
# 0     29.428    35.888        Ellie
# 1     32.738    33.068  Participant
# 2     36.598    40.948        Ellie
# 3     42.088    42.518  Participant
# 4     42.358    51.738        Ellie
#
#                                                value
# 0  hi i'm ellie thanks for coming in today i was ...
# 
Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm fine new york uh for business now um i do hospitality i'm in between jobs when um <sneeze> excuse me um third lemmi see twenty six years ago mm once a year the sun the beach palm trees <laught
# Session: 317_P
#   start_time stop_time      speaker  \
# 0      32.56    39.587        Ellie
# 1     40.485     46.73        Ellie
# 2      47.49     53.84        Ellie
# 3      54.52     55.02  Participant
# 4      56.09     56.52        Ellie
#
#                                                value
# 0  hi i'm ellie thanks for coming in today i was ...
# 1  i'm not a therapist but i'm here to learn abou...
# 2  and please feel free to tell me anything your ...
# 3                                                yes
# 4                                               okay
# Transcript preview: yes uh i'm okay a little sleepy right now i'm from new york um i wanted a change of environment and i wanted to start over somewhere um about two years ago um it took uh a bit of an a bit of adjustmen
# Session: 318_P
#   start_time stop_time speaker  \
# 0      12.43     15.41   Ellie
# 1      16.15     19.56   Ellie
# 2      20.38     26.86   Ellie
# 3      27.48     32.12   Ellie
# 4       32.7     33.93   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm alright los angeles california yep um the lights big city it's always something going on the traffic and that's it uh business administration and business management uh not that i'm doing some
# Session: 319_P
#   start_time stop_time speaker  \
# 0      48.58     51.65   Ellie
# 1      52.31     55.79   Ellie
# 2      56.48     63.05   Ellie
# 3      63.71     68.35   Ellie
# 4      68.94     70.12   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: sure mm okay los angeles um well <laughter> that's a good question um i like the familiarity with everything i know where everything is in the city mm that's all i can say right now so spread out so h
# Session: 320_P
#   start_time stop_time      speaker  \
# 0       6.02      7.05  Participant
# 1      60.84     63.75        Ellie
# 2     64.495    67.955        Ellie
# 3      68.72     75.12        Ellie
# 4       75.8     80.49        Ellie
#
#                                                value
# 0                                          [syncing]
# 1            hi i'm ellie thanks for coming in today
# 2  i was created to talk to people in a safe and ...
# 3  i'm not a therapist but i'm here to learn abou...
# 4  and please feel free to tell me anything your ...
# Transcript preview: [syncing] yes i'm a little nervous mm this is different california yes i like the beach um the weather mm mm so many people [laughter] yeah what do you mean what do i do now i don't know right now um
# Session: 321_P
#   start_time stop_time speaker  \
# 0     34.205    37.145   Ellie
# 1     37.865    41.265   Ellie
# 2     42.095    46.175   Ellie
# 3     46.595    48.615   Ellie
# 4       49.2    53.915   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3         i'll ask a few questions to get us started
# 4  and please feel free to tell me anything your ...
# Transcript preview: yeah i'm okay um chicago illinois mhm uh my husband's work was here in eighty four it was not easy for me it took about three years um just the move i moved away from my family so i was uncomfortable
# Session: 322_P
#   start_time stop_time speaker  \
# 0     39.185    42.185   Ellie
# 1     42.895    46.315   Ellie
# 2      47.18     51.21   Ellie
# 3     51.602    53.652   Ellie
# 4     54.275    58.885   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3         i'll ask a few questions to get us started
# 4  and please feel free to tell me anything your ...
# Transcript preview: yes fine thank you i'm originally from india yeah i'm sorry why <wh> why do i miss sorry why do i miss l_a oh about twenty years ago oh once every three four years um i mean the first <f> the first si
# Session: 323_P
#   start_time stop_time speaker  \
# 0      51.57     54.49   Ellie
# 1      55.22     58.63   Ellie
# 2      59.52     65.92   Ellie
# 3      66.59      71.2   Ellie
# 4      71.82     72.95   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: sure good chicago it's cold in chicago hmm oh i think in ninety nineteen eighty nine actually oh very simple very easy oh weather of course and i'm so easily located to san diego palm springs las vega
# Session: 324_P
#   start_time stop_time speaker  \
# 0      54.64     57.96   Ellie
# 1     58.405    62.025   Ellie
# 2      62.72     69.15   Ellie
# 3      69.74     74.46   Ellie
# 4     75.115    76.335   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything you a...
# 4                             are you okay with this
# Transcript preview: yeah yes fine how are you uh born and raise right here on the west side venice beach [laughter] everything the beach the weather uh the beach the weather um everything the girls uh nothing nothing tra
# Session: 325_P
#   start_time stop_time speaker  \
# 0       27.6     30.56   Ellie
# 1      31.41     34.68   Ellie
# 2      35.59     42.08   Ellie
# 3      42.67     47.38   Ellie
# 4       47.9     49.11   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything you'r...
# 4                             are you okay with this
# Transcript preview: yes um i'm fine this is a little bit strange you know talking to a virtual human um i was born i was born in l_a i was raised out in the suburbs um i've lived all over los angeles i've lived in the va
# Session: 326_P
#   start_time stop_time speaker  \
# 0      60.85     63.91   Ellie
# 1      64.54     67.91   Ellie
# 2      68.83     75.29   Ellie
# 3      75.88     80.55   Ellie
# 4      81.17     82.33   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm fine um ohio mmm <laughter> bigger city more opportunity um bigger city big city not often um i don't know uh there's phones i can call um let's see the water the ocean um the big city there's
# Session: 327_P
#   start_time stop_time speaker  \
# 0      36.22    39.555   Ellie
# 1     39.945    43.555   Ellie
# 2     44.195     50.65   Ellie
# 3       51.3     56.02   Ellie
# 4      56.56     57.84   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes fine thank you montreal canada i moved here with my mom when i was in high school yes oh it's very cold there in the winter and our summers are very short it was very easy i accustom pretty quick
# Session: 328_P
#   start_time stop_time speaker  \
# 0      29.68     32.71   Ellie
# 1      33.39     36.73   Ellie
# 2      37.63     44.11   Ellie
# 3      44.76     49.37   Ellie
# 4      49.99     51.11   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes <laughter> fine how are you uh watts california but now i live in west l_a <laughter> yes i love uh the sunshine i love the palm trees i love that um you're thirty minutes away from everything it'
# Session: 329_P
#   start_time stop_time speaker  \
# 0      26.04     29.38   Ellie
# 1      29.93     33.45   Ellie
# 2      34.11     40.73   Ellie
# 3      41.23        46   Ellie
# 4      46.55     47.87   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes pretty well from new york uh to go to college well to san diego to go to college and then later to l_a aerospace engineering um it was i was really good at math and science and i had a interest in
# Session: 330_P
#   start_time stop_time      speaker  \
# 0      33.07     33.83  Participant
# 1      33.39     36.36        Ellie
# 2       37.1     40.53        Ellie
# 3      41.34     47.84        Ellie
# 4      48.47     53.01        Ellie
#
#                                                value
# 0                                         <laughter>
# 1            hi i'm ellie thanks for coming in today
# 2  i was created to talk to people in a safe and ...
# 3  i'm not a therapist but i'm here to learn abou...
# 4  and please feel free to tell me anything your ...
# Transcript preview: <laughter> yes i'm okay with this very good l_a it's sunny and uh it's near the ocean <sigh> uh the traffic can make it difficult to drive around between different places and there's a lack of uh uh o
# Session: 331_P
#   start_time stop_time speaker  \
# 0      27.88     30.89   Ellie
# 1      31.57     34.93   Ellie
# 2      35.89     42.23   Ellie
# 3      42.96     47.61   Ellie
# 4       48.2     49.33   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes okay connecticut um to be an actor <laughter> well i moved to san francisco in ninety four and then i moved to atlanta in ninety six and then i moved out here to be an actor and i became a realtor
# Session: 332_P
#   start_time stop_time      speaker  \
# 0      86.85      93.9        Ellie
# 1      94.78    101.33        Ellie
# 2     101.87    106.53        Ellie
# 3     107.11    108.27        Ellie
# 4      108.5    108.94  Participant
#
#                                                value
# 0  hi i'm ellie thanks for coming in today i was ...
# 1  i'm not a therapist but i'm here to learn abou...
# 2  and please feel free to tell me anything your ...
# 3                             are you okay with this
# 4                                                yes
# Transcript preview: y
Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes <laughter> i uh didn't get much sleep last night and xxx and it's cold and i'm i'm just gonna get through the day didn't have haven't even haven't showered <laughter> in two days that's i need to
# Session: 360_P
#   start_time stop_time speaker  \
# 0      29.04     32.06   Ellie
# 1      32.84     36.15   Ellie
# 2      37.06      43.5   Ellie
# 3      44.11     48.76   Ellie
# 4      49.37     50.51   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm doing good and yourself inglewood the scenery the the places to eat um i just i i just love l_a the traffic the public transit that's about it yes getting to getting to new places and seeing n
# Session: 361_P
#   start_time stop_time speaker  \
# 0      20.67     23.69   Ellie
# 1      24.43     27.81   Ellie
# 2       28.6     35.19   Ellie
# 3      35.67     40.39   Ellie
# 4      41.03     42.18   Ellie
#
#                                                value
# 0            hi i'm ellie thanks for coming in today
# 1  i was created to talk to people in a safe and ...
# 2  i'm not a therapist but i'm here to learn abou...
# 3  and please feel free to tell me anything your ...
# 4                             are you okay with this
# Transcript preview: yes i'm doing great how about you i'm born in the u_s i was born in uh orlando florida um my parents my dad had a lot of friends in los angeles so uh we decided to move here um it was pretty different
# Session: 362_P
#   start_time stop_time speaker  \
# 0       8.96     11.93   Ellie
# 1      12.67     16.11   Ellie
# 2       16.9     23.37   Ellie
# 3      23.93     28.64   Ellie
# 4      29.16     30.47   Ellie
#
#                                                value
# ...
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes good thank you el segundo right down the street the beach the smog i try to when i have time being away from home getting away i recently went to palm springs with my wife and my friends u
# Session: 476_P
#   start_time stop_time      speaker  \
# 0      19.02     19.86  Participant
# 1     31.552    53.092        Ellie
# 2      53.72     54.31  Participant
# 3     55.133    55.593        Ellie
# 4     56.791    59.061        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                       uh yeah sure
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> uh yeah sure <laughter> i'm alright uh i'm in a weird test study right now uh i'm from los angeles mhm <ss> all kinds of different things to do in this city uh well i don't know each each area
# Session: 477_P
#   start_time stop_time      speaker  \
# 0      11.54     12.35  Participant
# 1     32.789    54.329        Ellie
# 2     54.075    54.865  Participant
# 3     55.674    56.134        Ellie
# 4     57.244    59.514        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                         yes thanks
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes thanks i'm well thank you how are you i grew up in oklahoma mhm um i moved to l_a about five and a half years ago so i used to be on the west <we> on the east coast and then i decided i wa
# Session: 478_P
#   start_time stop_time      speaker  \
# 0       37.5     38.35  Participant
# 1     57.166    78.706        Ellie
# 2      78.91     79.21  Participant
# 3     80.873    81.333        Ellie
# 4     82.653    84.923        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes uh good thanks the east coast for work uh rarely i prefer it out here uh i it's um not as nice as the lifestyle out here i like the weather better and uh just a lot of things about living
# Session: 479_P
#   start_time stop_time      speaker  \
# 0     11.429    12.289  Participant
# 1     31.877    53.417        Ellie
# 2     54.272    54.682  Participant
# 3     55.828    56.288        Ellie
# 4     57.815    60.085        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes okay l_a uh the smog traffic tickets high rent uh everything um like um the cost of living the smog yeah <clears throat> not anymore uh don't have the time um the meeting new people the fo
# Session: 480_P
#   start_time stop_time      speaker               value
# 0      20.26     21.19  Participant             <synch>
# 1      57.23     57.68  Participant                 yes
# 2      62.29     63.35  Participant  i'm fine thank you
# 3      66.94     67.87  Participant       new york city
# 4     70.425    70.885  Participant                 yes
# Transcript preview: <synch> yes i'm fine thank you new york city yes uh seventy <s> nineteen seventy five <f> five <laughter> about <bout> once a year both urban uh big cities but uh east coast has a little bit maybe a l
# Session: 481_P
#   start_time stop_time      speaker  \
# 0      26.64     27.57  Participant
# 1     42.645    64.185        Ellie
# 2      64.67     65.15  Participant
# 3      65.68     66.09  Participant
# 4     66.042    66.502        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                               yeah
# 3                                               i am
# 4                                okay_confirm (okay)
# Transcript preview: <synch> yeah i am um good to moderate los angeles yeah i'm from um just a lot of different kinds of people and um eh i love the weather most of the time and um great creative scene i'm i'm really into
# Session: 482_P
#   start_time stop_time      speaker  \
# 0      12.42     13.29  Participant
# 1      27.85     49.39        Ellie
# 2      49.47     49.99  Participant
# 3     51.212    51.672        Ellie
# 4     52.809    55.079        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes i'm doing fine i was born in texas and i moved to california when i was three and grew up here in california yeah i was yes uh i've never been back there um don't have any relatives there
# Session: 483_P
#   start_time stop_time      speaker  \
# 0       8.15      8.94  Participant
# 1     24.522    46.062        Ellie
# 2      46.25     46.66  Participant
# 3     47.519    47.979        Ellie
# 4     49.276    51.546        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                               sure
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> sure <laughter> mm good i guess new orleans louisiana uh two thousand five i used to go back often but not much anymore uh just things happened uh <laughter> uh well guess you're not programme
# Session: 484_P
#   start_time stop_time      speaker  \
# 0      10.91     11.78  Participant
# 1      23.06     23.62  Participant
# 2     25.162    46.702        Ellie
# 3      46.57     47.22  Participant
# 4     47.737    48.197        Ellie
#
#                                                value
# 0                                            <synch>
# 1                                         <laughter>
# 2  IntroV4Confirmation (hi i'm ellie thanks for c...
# 3                                                yes
# 4                                okay_confirm (okay)
# Transcript preview: <synch> <laughter> yes i'm doing well i was born in oakland um <sigh> all the different areas of the city uh the different cultures that are here the traffic the um lack of public transportation and t
# Session: 485_P
#   start_time stop_time      speaker  \
# 0      37.02     37.81  Participant
# 1     62.612    84.152        Ellie
# 2      84.34     84.75  Participant
# 3     85.664    86.124        Ellie
# 4     87.322    89.592        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes i'm not bad i'm a little tired but okay uh from saint louis missouri yep uh two months ago uh not often i think i'm out here for good now uh smaller town less people everyone kinda acts di
# Session: 486_P
#   start_time stop_time      speaker  \
# 0      17.07     17.89  Participant
# 1     34.363    55.903        Ellie
# 2      56.04     56.53  Participant
# 3     57.086    57.546        Ellie
# 4     58.738    61.008        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes i'm feel great i am from saint louis missouri born and raised yes i've been here a couple times i just recently moved back two months ago saint louis is quite slower uh to take care of a g
# Session: 487_P
#   start_time stop_time      speaker  \
# 0      12.34     13.19  Participant
# 1     32.171    53.711        Ellie
# 2      54.48     54.98  Participant
# 3     57.124    57.584        Ellie
# 4     58.854    61.124        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes i'm fine thank you detroit michigan yes i moved to l_a myself in two thousand and seven but my family came here many more years ago more like forty years ago uh i don't go back to detroit
# Session: 488_P
#   start_time stop_time      speaker  \
# 0      11.71     12.56  Participant
# 1     34.036    55.576        Ellie
# 2      55.99     56.75  Participant
# 3     57.324    57.784        Ellie
# 4     59.012    61.282        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes fine oh san fernando valley uh well i really like the culture i love going to museums and being able to go at night and having lots of people around it's spread out a lot and it's a pain i
# Session: 489_P
#   start_time stop_time      speaker  \
# 0      21.43     22.32  Participant
# 1     36.732    58.272        Ellie
# 2      59.09     59.47  Participant
# 3     59.977    60.437        Ellie
# 4     61.505    63.775        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes i'm doing well thank you san luis obispo yes four years ago about once a month small quiet fresh air less people it's nice i went to school in los angeles <laughter> i studied music indust
# Session: 490_P
#   start_time stop_time      speaker  \
# 0       9.25     10.13  Participant
# 1     22.735    44.275        Ellie
# 2      44.43     44.66  Participant
# 3     45.407    45.867        Ellie
# 4     46.937    49.207        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                               yeah
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yeah i'm doing already how are you doing northern illinois two and a half years ago haven't yet since i been here haven't had a chance to gonna go back later this year colder or warmer work ye
# Session: 491_P
#   start_time stop_time      speaker  \
# 0       52.8      53.7  Participant
# 1         66     87.54        Ellie
# 2      88.53     88.96  Participant
# 3     89.733    90.193        Ellie
# 4     91.412    93.682        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes huh overwhelmed i have a funeral to attend tomorrow i found out from my doctor i got some health issues it is hard honey i am just putting one foot in front of the other and just trying to
# Session: 492_P
#   start_time stop_time      speaker  \
# 0      10.77     11.65  Participant
# 1     32.152    53.692        Ellie
# 2      53.54     54.06  Participant
# 3     55.422    55.882        Ellie
# 4     56.845    59.115        Ellie
#
#                                                value
# 0                                            <synch>
# 1  IntroV4Confirmation (hi i'm ellie thanks for c...
# 2                                                yes
# 3                                okay_confirm (okay)
# 4            how_doingV (so how are you doing today)
# Transcript preview: <synch> yes doing pretty good thank you maryland yes eighty five yeah yeah it is a long time um not as often as i'd like um out of work so you know the money issue yeah um maryland uh is different it
#
# Session summary table:
#     session  audio_duration  sample_rate  transcript_word_count  num_responses
# 0     300_P           648.5        16000                    352             87
# 1     301_P           823.9        16000                   1475            104
# 2     302_P           758.8        16000                    614             97
# 3     303_P           985.3        16000                   1807            103
# 4     304_P           792.6        16000                    957            104
# ..      ...             ...          ...                    ...            ...
# 184   488_P           884.9        16000                   1413            138
# 185   489_P           704.7        16000                    491            117
# 186   490_P           691.3        16000                    592             97
# 187   491_P           881.7        16000                   1241            146
# 188   492_P           912.5        16000                   1259            220
#
# [189 rows x 5 columns]
# Summary statistics:
#         audio_duration  sample_rate  transcript_word_count  num_responses
# count      189.000000        189.0             189.000000     189.000000
# mean       956.331210      16000.0            1460.253968     171.285714
# std        269.961192          0.0             801.909980      74.972781
# min        414.800000      16000.0             167.000000      42.000000
# 25%        785.600000      16000.0             889.000000     118.000000
# 50%        911.700000      16000.0            1275.000000     155.000000
# 75%       1056.800000      16000.0            1809.000000     211.000000
# max       1966.200000      16000.0            4611.000000     386.000000
# Sessions processed: 189
# Sessions with audio: 189
# Sessions with transcript: 189
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   session                189 non-null    object
#  1   audio_duration         189 non-null    float64
#  2   sample_rate            189 non-null    int64
#  3   transcript_word_count  189 non-null    int64
#  4   num_responses          189 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 7.5+ KB
# None

# %%
total_df.isnull().sum()
# Out:
# session                  0
# audio_duration           0
# sample_rate              0
# transcript_word_count    0
# num_responses            0
# dtype: int64

# %%
scripts_path = Path("./DAICWOZ_MAIN/splits")
print(f"Searching for all .csv files in {scripts_path.resolve()}...")
all_files = list(scripts_path.rglob("*.csv"))

if not all_files:
    print("ERROR: No .csv files found in that directory")
    raise FileNotFoundError(f"No CSV files found in '{scripts_path}'")
else:
    print(f"Found {len(all_files)} files. Reading...")
    all_dfs = []

    for file_path in all_files:
        print(f"  Reading {file_path.name}...")
        try:
            df = pd.read_csv(file_path)
            
            split = None
            if 'train' in file_path.name.lower():
                split = 'train'
            elif 'dev' in file_path.name.lower():
                split = 'dev'
            elif 'test' in file_path.name.lower():
                split = 'test'
            
            # Find score column
            score_col = 'PHQ8_Score' if 'PHQ8_Score' in df.columns else 'PHQ_Score'
            
            # Find binary column
            binary_col = 'PHQ8_Binary' if 'PHQ8_Binary' in df.columns else 'PHQ_Binary'

            # Check if all required columns are present
            if 'Participant_ID' in df.columns and score_col in df.columns and binary_col in df.columns and split:
                # Rename columns to a standard name
                df_renamed = df.rename(columns={
                    score_col: 'PHQ8_Score',
                    binary_col: 'PHQ8_Binary'
                })
                # --- EDIT: Add the split column ---
                df_renamed['split'] = split
                all_dfs.append(df_renamed[['Participant_ID', 'PHQ8_Score', 'PHQ8_Binary', 'split']])
            else:
                print(f"    Skipping {file_path.name}: missing required columns or split name.")
        except Exception as e:
            print(f"    Error reading {file_path.name}: {e}")

if not all_dfs:
    print(" ERROR: No files with the required columns were found.")
    raise ValueError("No data found with 'Participant_ID', Score, and Binary columns.")
else:
    full_df = pd.concat(all_dfs, ignore_index=True)
    mapping_df = full_df.dropna(subset=['Participant_ID'])
    mapping_df = mapping_df[['Participant_ID', 'PHQ8_Score', 'PHQ8_Binary', 'split']].copy()
    mapping_df = mapping_df.drop_duplicates(subset=['Participant_ID'])
    mapping_df = mapping_df.set_index('Participant_ID')
    mapping_df = mapping_df.sort_index()

    print("\nMapping DataFrame created.")
    print(mapping_df.head(10))

    phq_score_map = {str(int(k)): v for k, v in mapping_df['PHQ8_Score'].to_dict().items()}
    phq_binary_map = {str(int(k)): v for k, v in mapping_df['PHQ8_Binary'].to_dict().items()}
    split_map = {str(int(k)): v for k, v in mapping_df['split'].to_dict().items()}
# Out:
# Searching for all .csv files in C:\Users\himan\DLT\DAICWOZ_MAIN\splits...
# Found 7 files. Reading...
#   Reading dev_split_Depression_AVEC2017.csv...
#   Reading full_test_split.csv...
#   Reading train_split_Depression_AVEC2017.csv...
#   Reading dev_split_Depression_AVEC2017-checkpoint.csv...
#   Reading full_test_split-checkpoint.csv...
#   Reading test_split_Depression_AVEC2017-checkpoint.csv...
#     Skipping test_split_Depression_AVEC2017-checkpoint.csv: missing required columns or split name.
#   Reading train_split_Depression_AVEC2017-checkpoint.csv...
#
# Mapping DataFrame created.
#                 PHQ8_Score  PHQ8_Binary  split
# Participant_ID
# 300                      2            0   test
# 301                      3            0   test
# 302                      4            0    dev
# 303                      0            0  train
# 304                      6            0  train
# 305                      7            0  train
# 306                      0            0   test
# 307                      4            0    dev
# 308                     22            1   test
# 309                     15            1   test

# %%
PHQ_MAX_SCORE = 24

print("\nApplying maps to 'total_df'...")
total_df['Participant_ID'] = total_df['session'].str.extract(r'(\d+)')[0]

# Map the score
total_df['PHQ_Score_0_24'] = total_df['Participant_ID'].map(phq_score_map).astype(float)

# Map the binary value directly
total_df['PHQ8_Binary'] = total_df['Participant_ID'].map(phq_binary_map).astype(float)

# --- EDIT: Map the split ---
total_df['split'] = total_df['Participant_ID'].map(split_map)

# Derive the 0-10 score
total_df['PHQ_Score_0_10_Target'] = (total_df['PHQ_Score_0_24'] / PHQ_MAX_SCORE) * 10.0

# Create the final labeled DataFrame
labeled_df = total_df[total_df['PHQ_Score_0_24'].notna()].copy()
print(total_df.head())
print(labeled_df.head())
# Out:
# Applying maps to 'total_df'...
#   session  audio_duration  sample_rate  transcript_word_count  num_responses  \
# 0   300_P           648.5        16000                    352             87
# 1   301_P           823.9        16000                   1475            104
# 2   302_P           758.8        16000                    614             97
# 3   303_P           985.3        16000                   1807            103
# 4   304_P           792.6        16000                    957            104
#
#   Participant_ID  PHQ_Score_0_24  PHQ8_Binary  PHQ_Score_0_10_Target  split
# 0            300             2.0          0.0               0.833333   test
# 1            301             3.0          0.0               1.250000   test
# 2            302             4.0          0.0               1.666667    dev
# 3            303             0.0          0.0               0.000000  train
# 4            304             6.0          0.0               2.500000  train
#   session  audio_duration  sample_rate  transcript_word_count  num_responses  \
# 0   300_P           648.5        16000                    352             87
# 1   301_P           823.9        16000                   1475            104
# 2   302_P           758.8        16000                    614             97
# 3   303_P           985.3        16000                   1807            103
# 4   304_P           792.6        16000                    957            104
#
#   Participant_ID  PHQ_Score_0_24  PHQ8_Binary  PHQ_Score_0_10_Target  split
# 0            300             2.0          0.0               0.833333   test
# 1            301             3.0          0.0               1.250000   test
# 2            302             4.0          0.0               1.666667    dev
# 3            303             0.0          0.0               0.000000  train
# 4            304             6.0          0.0               2.500000  train

# %% [markdown]
# ## Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Simple bar plot (counts of 0 and 1)
plt.figure(figsize=(5,4))
sns.countplot(x=total_df['PHQ8_Binary'])
plt.title('Binary Depression Label Distribution (All Sessions)')
plt.xlabel('PHQ8_Binary Label')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
plt.hist(total_df['audio_duration'].dropna(), bins=8, color="purple")
plt.title('Histogram of Audio Durations')
plt.xlabel('Duration (seconds)')
plt.ylabel('Number of Sessions')
plt.show()

plt.figure(figsize=(8,4))
plt.hist(total_df['transcript_word_count'], bins=8, color="teal")
plt.title('Histogram of Transcript Word Counts')
plt.xlabel('Words per Transcript')
plt.ylabel('Number of Sessions')
plt.show()

plt.figure(figsize=(6,6))
plt.scatter(total_df['audio_duration'], total_df['transcript_word_count'], color="navy")
plt.title('Transcript Length vs Audio Duration')
plt.xlabel('Audio Duration (s)')
plt.ylabel('Transcript Word Count')
plt.grid()
plt.show()

# %%
import seaborn as sns
if 'split' in labeled_df.columns and 'PHQ8_Binary' in labeled_df.columns:
    print("\nPlotting data...")
    
    # Ensure 'PHQ8_Binary' is an integer for cleaner plot labels
    labeled_df['PHQ8_Binary'] = labeled_df['PHQ8_Binary'].astype(int)

    plt.figure(figsize=(8, 5))
    sns.countplot(x='split', hue='PHQ8_Binary', data=labeled_df, palette='pastel')
    plt.title('Binary Depression Label Distribution Across Splits')
    plt.xlabel('Data Split')
    plt.ylabel('Count')
    plt.legend(title='PHQ8_Binary (1=Depressed)')
    plt.grid(axis='y', alpha=0.5)
    plt.show()
else:
    print("\n--- ERROR: 'labeled_df' is missing 'split' or 'PHQ8_Binary' column. ---")
    print(f"Columns available: {labeled_df.columns.tolist()}")
# Out:
# Plotting data...

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='split', y='PHQ_Score_0_24', data=labeled_df, palette='Set2')
plt.title('Continuous PHQ-8 Score Distribution (0-24) Across Splits')
plt.xlabel('Data Split')
plt.ylabel('PHQ-8 Score (0-24)')
# Mark the clinical cutoff (PHQ-8 >= 10)
plt.axhline(y=10, color='r', linestyle='--', label='Clinical Cutoff (PHQ=10)')
plt.legend()
plt.grid(axis='y', alpha=0.5)
plt.show()
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_14592\248072145.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='split', y='PHQ_Score_0_24', data=labeled_df, palette='Set2')

# %% [markdown]
# Notes & Observations from EDA
# 1. Summary Statistics:
#
# The session data is well-formed: all sessions contain non-null audio duration, sample rate, transcript word count, and response count.
#
# "audio_duration" values range from around 600 to 1600 seconds (10–27 minutes), showing moderate consistency in interview length, with a few longer outliers.
#
# "transcript_word_count" is variable: most transcripts are clustered between 1500 and 2500 words. A few outlier sessions extend to 4500+ words, likely reflecting more talkative participants or longer interviews.
#
# The number of participant utterances per session appears consistent given similar response counts (as shown in the table output).
#
# 2. Plots Analysis:
#
# The Histogram of Audio Durations shows that most sessions are centered near 800–1000 seconds, but a few sessions are much longer, indicating potential interview outliers or errors.
#
# The Transcript Word Count Histogram reveals that most sessions cluster between 1500 and 2500 words, but outliers reach much higher values—suggesting that certain interviews might either be longer, more informative, or possibly have redundant/duplicated transcript lines.
#
# The Scatter Plot (Transcript Length vs Audio Duration) shows a generally positive trend: longer audio durations usually correspond to longer transcripts. However, some points deviate—sessions with longer audio but lower word count indicate more silence or less speech, while high word count vs. shorter audio might reveal transcription artifacts.
#
# 3. Data Integrity:
#
# All columns report non-null dtypes after .info(), confirming clean loading.
#
# The data is suitable for downstream modeling: you can filter or flag outliers for further inspection if needed.

# %% [markdown]
# ## Map Session IDs to Label Splits

# %%
print("Initial summary table:")
display(total_df.head(18))
# Out:
# Initial summary table:
#    session  audio_duration  sample_rate  transcript_word_count  num_responses  \
# 0    300_P           648.5        16000                    352             87
# 1    301_P           823.9        16000                   1475            104
# 2    302_P           758.8        16000                    614             97
# 3    303_P           985.3        16000                   1807            103
# 4    304_P           792.6        16000                    957            104
# 5    305_P          1704.0        16000                   2969            288
# 6    306_P           858.1        16000                   1530            108
# 7    307_P          1238.8        16000                   2548            186
# 8    308_P           867.6        16000                    889            154
# 9    309_P           705.8        16000                    697             94
# 10   310_P           844.9        16000                   1137            148
# 11   311_P           785.6        16000                    643            129
# 12   312_P           790.0        16000                   1187            126
# 13   313_P           753.8        16000                    751            114
# 14   314_P          1546.7        16000                   3289            375
# 15   315_P           975.4        16000                   1369            135
# 16   316_P           869.0        16000                    632            136
# 17   317_P           804.9        16000                    642            112
#
#    Participant_ID  PHQ_Score_0_24  PHQ8_Binary  PHQ_Score_0_10_Target  split
# 0             300             2.0          0.0               0.833333   test
# 1             301             3.0          0.0               1.250000   test
# 2             302             4.0          0.0               1.666667    dev
# 3             303             0.0          0.0               0.000000  train
# 4             304             6.0          0.0               2.500000  train
# 5             305             7.0          0.0               2.916667  train
# 6             306             0.0          0.0               0.000000   test
# 7             307             4.0          0.0               1.666667    dev
# 8             308            22.0          1.0               9.166667   test
# 9             309            15.0          1.0               6.250000   test
# 10            310             4.0          0.0               1.666667  train
# 11            311            21.0          1.0               8.750000   test
# 12            312             2.0          0.0               0.833333  train
# 13            313             7.0          0.0               2.916667  train
# 14            314             1.0          0.0               0.416667   test
# 15            315             2.0          0.0               0.833333  train
# 16            316             6.0          0.0               2.500000  train
# 17            317             8.0          0.0               3.333333  train

# %%
import random
random.seed(10)
sessions_shuffled = labeled_df['session'].tolist()
random.shuffle(sessions_shuffled)
n_train, n_dev = 12, 3
train_sessions = sessions_shuffled[:n_train]
dev_sessions   = sessions_shuffled[n_train:n_train + n_dev]
test_sessions  = sessions_shuffled[n_train + n_dev:]
labeled_df['split'] = labeled_df['session'].apply(
    lambda s: 'train' if s in train_sessions else ('dev' if s in dev_sessions else 'test')
)

# %%
y_binary = labeled_df['PHQ8_Binary'].astype(int).to_numpy()
y_regression_target_0_10 = labeled_df['PHQ_Score_0_10_Target'].to_numpy()
y_regression_target_0_24 = labeled_df['PHQ_Score_0_24'].to_numpy()

train_mask = labeled_df['split'] == 'train'
dev_mask   = labeled_df['split'] == 'dev'
test_mask  = labeled_df['split'] == 'test'

# Targets for MTL: [Binary_Head_Target, Regression_Head_Target (0-10)]
y_train_mtl = [y_binary[train_mask], y_regression_target_0_10[train_mask]]
y_dev_mtl   = [y_binary[dev_mask], y_regression_target_0_10[dev_mask]]
y_test_mtl  = [y_binary[test_mask], y_regression_target_0_10[test_mask]]

print("Regression Target (0-10 Scale) Sample (Train):", y_train_mtl[1][:5].round(2))
# Out:
# Regression Target (0-10 Scale) Sample (Train): [1.67 3.33 7.5  4.58 0.  ]

# %% [markdown]
# ## Text Data Preparation (Transcript to Input String)

# %%
# Preview text and word counts for each session
for session in total_df['session']:
    print(f"\nSession: {session}")
    print("Preview:", text_data[session][:150])
    print(f"Word count: {len(text_data[session].split())}")

# Histogram of transcript lengths
lengths = [len(text_data[session].split()) for session in total_df['session']]
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.hist(lengths, bins=8, color='goldenrod', edgecolor='black')
plt.title("Distribution of Transcript Lengths (Words)")
plt.xlabel("Word Count per Session")
plt.ylabel("Num Sessions")
plt.show()
# Out:
# Session: 300_P
# Preview: good atlanta georgia um my parents are from here um i love it i like the weather i like the opportunities um yes um it took a minute somewhat easy con
# Word count: 352
#
# Session: 301_P
# Preview: thank you mmm k i'm doing good thank you i'm from los angeles oh great i live in west los angeles the west side it's alright i xxx no i live alone so
# Word count: 1475
#
# Session: 302_P
# Preview: i'm fine how about yourself i'm from los angeles california what part okay um all my family's here friends a mixture of people and a lot of things to
# Word count: 614
#
# Session: 303_P
# Preview: okay how 'bout yourself here in california yeah oh well that it's big and broad there's a lot to do a lot of um um job opportunities than other states
# Word count: 1807
#
# Session: 304_P
# Preview: i'm doing good um from los angeles california um the cool weather the beaches the people the schools um child development yes to be a teacher for spec
# Word count: 957
#
# Session: 305_P
# Preview: i'm doing alright uh originally i'm from california uh born in glendale i'm not too happy with it uh just unemployed at the moment but uh actively see
# Word count: 2969
#
# Session: 306_P
# Preview: fine uh colorado mhm uh career career possibilities uh paralegal uh for further education for the weather for a friend [laughter] not often at all now
# Word count: 1530
#
# Session: 307_P
# Preview: <laughter> um moscow um my family moved to the u_s and then i moved down here eventually for college  uh it took a long time to i've been living here
# Word count: 2548
#
# Session: 308_P
# Preview: los angeles california yes um the southern california lifestyle the beaches the um active lifestyle the traffic the pretentious people um my teachers
# Word count: 889
#
# Session: 309_P
# Preview: <laughter> <laughter> yeah <laughter> <laughter> i'm doing good <laughter> uh arizona uh because of acting and other stuff like that entertain <entert
# Word count: 697
#
# Session: 310_P
# Preview: yes it's okay <laughter> fine <laughter> i live in hollywood uh seattle <laughter> uh it's kind of a vague question um <laughter> just needed a change
# Word count: 1137
#
# Session: 311_P
# Preview: yes okay uh when'd i move to l_a um moved here a long time ago to live to go to work um well arizona and colorado i don't uh money don't have the mone
# Word count: 643
#
# Session: 312_P
# Preview: yes fine how about you here yes the weather weather mainly yeah the main <ma> the weather sorry not the people well some of the people stuff like that
# Word count: 1187
#
# Session: 313_P
# Preview: sure uh okay i guess not bad not good so so denver colorado uh to pursue job opportunities uh about two years ago uh once or twice a year uh i really
# Word count: 751
#
# Session: 314_P
# Preview: yes quite well feel good los angeles california here mhm one of the few um native born los angelinos i uh home school my ten year old son and uh i'm a
# Word count: 3289
#
# Session: 315_P
# Preview: alright yes okay and you inglewood california yes no uh it's okay um you mean my girlfriend and my daughter yes they're they're okay it's okay it's co
# Word count: 1369
#
# Session: 316_P
# Preview: yes i'm fine new york uh for business now um i do hospitality i'm in between jobs when um <sneeze> excuse me um third lemmi see twenty six years ago m
# Word count: 632
#
# Session: 317_P
# Preview: yes uh i'm okay a little sleepy right now i'm from new york um i wanted a change of environment and i wanted to start over somewhere um about two year
# Word count: 642
#
# Session: 318_P
# Preview: yes i'm alright los angeles california yep um the lights big city it's always something going on the traffic and that's it uh business administration
# Word count: 698
#
# Session: 319_P
# Preview: sure mm okay los angeles um well <laughter> that's a good question um i like the familiarity with everything i know where everything is in the city mm
# Word count: 681
#
# Session: 320_P
# Preview: [syncing] yes i'm a little nervous mm this is different california yes i like the beach um the weather mm mm so many people [laughter] yeah what do yo
# Word count: 756
#
# Session: 321_P
# Preview: yeah i'm okay um chicago illinois mhm uh my husband's work was here in eighty four it was not easy for me it took about three years um just the move i
# Word count: 917
#
# Session: 322_P
# Preview: yes fine thank you i'm originally from india yeah i'm sorry why <wh> why do i miss sorry why do i miss l_a oh about twenty years ago oh once every thr
# Word count: 1567
#
# Session: 323_P
# Preview: sure good chicago it's cold in chicago hmm oh i think in ninety nineteen eighty nine actually oh very simple very easy oh weather of course and i'm so
# Word count: 1342
#
# Session: 324_P
# Preview: yeah yes fine how are you uh born and raise right here on the west side venice beach [laughter] everything the beach the weather uh the beach the weat
# Word count: 871
#
# Session: 325_P
# Preview: yes um i'm fine this is a little bit strange you know talking to a virtual human um i was born i was born in l_a i was raised out in the suburbs um i'
# Word count: 1799
#
# Session: 326_P
# Preview: yes i'm fine um ohio mmm <laughter> bigger city more opportunity um bigger city big city not often um i don't know uh there's phones i can call um let
# Word count: 511
#
# Session: 327_P
# Preview: yes fine thank you montreal canada i moved here with my mom when i was in high school yes oh it's very cold there in the winter and our summers are ve
# Word count: 784
#
# Session: 328_P
# Preview: yes <laughter> fine how are you uh watts california but now i live in west l_a <laughter> yes i love uh the sunshine i love the palm trees i love that
# Word count: 2028
#
# Session: 329_P
# Preview: yes pretty well from new york uh to go to college well to san diego to go to college and then later to l_a aerospace engineering um it was i was reall
# Word count: 985
#
# Session: 330_P
# Preview: <laughter> yes i'm okay with this very good l_a it's sunny and uh it's near the ocean <sigh> uh the traffic can make it difficult to drive around betw
# Word count: 482
#
# Session: 331_P
# Preview: yes okay connecticut um to be an actor <laughter> well i moved to san francisco in ninety four and then i moved to atlanta in ninety six and then i mo
# Word count: 1477
#
# Session: 332_P
# Preview: yes fine just tired california from hollywood uh not too much <laughter> there's not too many things i like about it uh the people um it's not clean t
# Word count: 888
#
# Session: 333_P
# Preview: yes very well new york just turn the volume up a little bit <laughter> uh for a change yeah it's good i wanted <wa> i wanted to i wanted to see what l
# Word count: 1350
#
# Session: 334_P
# Preview: okay yes pretty good a little tired seattle washington uh when i was eighteen my mom and dad decided we wanted to move to california and uh so we move
# Word count: 1498
#
# Session: 335_P
# Preview: yes i'm okay uh i'm from here originally los angeles mhm um i like the weather and my family's here which is why i'm here i moved away for a while uh
# Word count: 1393
#
# Session: 336_P
# Preview: hello sure good a little tired indianapolis indiana uh i'm a singer i like singing um diversity my girlfriend's uh from taiwan so it's dealing with di
# Word count: 977
#
# Session: 337_P
# Preview: yeah i'm doing okay how are you doing i'm originally from like a suburb <su> a suburb of l_a from the san gabriel valley i like the diversity i like t
# Word count: 4611
#
# Session: 338_P
# Preview: yes i'm doing fine i'm from los angeles california wow wonderful weather um outdoor activities all the time too crowded pollution the norm i studied c
# Word count: 843
#
# Session: 339_P
# Preview: yes um i'm okay i was born in san bernardino california yes um i'm staying with a sister in north hollywood um she makes it as comfortable as possible
# Word count: 1012
#
# Session: 340_P
# Preview: yeah i'm okay fine pensacola florida uh i met my wife in mississippi and she stays out here so i moved to l_a what two thousand four about yeah about
# Word count: 1275
#
# Session: 362_P
# Preview: yes good from california i like the eh arts and entertainments i like the uh you have a lot of freedom to work in a lot of different fields um i like
# Word count: 782
#
# Session: 363_P
# Preview: <synch> yes good how are you i am from los angeles yes um it's uh center of everything eh you can get to all the places you need to go to uh eh withou
# Word count: 2171
#
# Session: 364_P
# Preview: <synch> i am i feel pretty good i'm wide awake i had an good breakfast and a nice cup of coffee and uh i have an easy day today so i am just gonna cha
# Word count: 3997
#
# Session: 365_P
# Preview: <synch> sure i'm doing alright new jersey yes three months ago not very often uh it's much different uh i don't know it's just <laughter> it's a lot m
# Word count: 2309
#
# Session: 366_P
# Preview: <synch> yeah i'm great and you uh los angeles california uh <sigh> i like the diversity i feel l_a by itself is a country there's so much to do so muc
# Word count: 2548
#
# Session: 367_P
# Preview: <sync> yes i'm okay um i'm a little pensive i guess a little uh down but more or less okay i was born in annapolis maryland on the east coast original
# Word count: 3036
#
# Session: 368_P
# Preview: <synch> <sniffle> yeah i'm okay with it um i'm okay i'm okay um i guess scrubbed_entry i'm basically an l_a kinda guy cool um you know the weather it'
# Word count: 3524
#
# Session: 369_P
# Preview: <sync> <ellie starts> sure yeah i'm doing great thank you for asking um you know how about yourself <laughter> oh awesome uh i'm from guatemala my par
# Word count: 2221
#
# Session: 370_P
# Preview: <synch> yeah i'm doing pretty okay thanks for asking how are you uh i'm from here in l_a i grew up in the san fernando valley yeah uh <sigh> well i i
# Word count: 3086
#
# Session: 371_P
# Preview: <synch> yes i'm doing pretty good thank you i was born in the san fernando valley in california really <laughter> uh i love the beaches i like uh ther
# Word count: 821
#
# Session: 372_P
# Preview: <synch> yes um pretty good kind of <laughter> yeah <laughter> about los angeles yes the thing i like about l_a the weather it's not easy to meet peopl
# Word count: 2170
#
# Session: 373_P
# Preview: <synch> yes uh doing okay doing okay uh north carolina yep uh almost four years ago um i graduated college had an internship out here uh for a product
# Word count: 3588
#
# Session: 374_P
# Preview: <synch> yes pretty good alexandria virginia mhm uh i moved to l_a uh end of two thousand one yeah it's crazy <laughter> um a couple times a year usual
# Word count: 2378
#
# Session: 375_P
# Preview: <synch> yes good it's been a nice day the south bay can i ask you that question too oh okay that's where i'm from basically but like the south bay of
# Word count: 535
#
# Session: 376_P
# Preview: <synch> yes i'm doing okay it's still morning so i'm from the east coast massachusetts yes um i moved to l_a when i was a child with my parents pretty
# Word count: 1720
#
# Session: 377_P
# Preview: <synch> yeah go ahead um i'm okay i grew up in wisconsin and i lived in colorado for a bit and then i lived overseas for a little while then i moved t
# Word count: 2354
#
# Session: 378_P
# Preview: <synch> yes pretty good i grew up in boston about thirty years ago yep not too often maybe once a year sometimes less oh i love living in l_a i don't
# Word count: 1304
#
# Session: 379_P
# Preview: <synch> <sniffle> <sniffle> yes i'm feeling okay little bit tired but for the most part feeling pretty good i'm actually originally from woodland hill
# Word count: 2521
#
# Session: 380_P
# Preview: <synch> sure i'm fine i'm doing alright um yeah i'm from maryland yeah from maryland washington d_c area uh like five weeks ago <laughter> <laughter>
# Word count: 3933
#
# Session: 381_P
# Preview: <synch> yes okay from santa monica uh the people mostly <sigh> well the people also <laughter> <laughter> uh no not a lot well i can't afford to trave
# Word count: 1650
#
# Session: 382_P
# Preview: <synch> sure i'm doing fine i'm from columbia south carolina yep uh two thousand four yeah <laughter> uh once a year for christmas break uh a lot slow
# Word count: 1111
#
# Session: 383_P
# Preview: <sync> yeah i'm totally fine it be confidential or not you know my words <wo> my words are everybody's get wild <laughter> i'm doing pretty good hangi
# Word count: 2109
#
# Session: 384_P
# Preview: <sync> yes i'm doing fine indiana yes uh i don't know maybe ten years ago never uh just don't like the cold weather l_a has beautiful weather and acti
# Word count: 1070
#
# Session: 385_P
# Preview: <sync> yes good how are you los angeles uh weather entertainment traffic no too <t> too many people business uh just fun thing to do yes nothing much
# Word count: 167
#
# Session: 386_P
# Preview: <synch> yes oh um fine a little tired but uh i found out my thyroid is i think acting up so <laughter> i was born in canada and but i've lived in cali
# Word count: 2063
#
# Session: 387_P
# Preview: <synch> hmm okay sure great philadelphia about five years ago once a year it doesn't l_a is a lot more fun for acting sure uh when i was young it was
# Word count: 545
#
# Session: 388_P
# Preview: <sync> yes doing alright from passaic new jersey yes uh about five years ago try to go back every year uh there's a lot more people change of scenery
# Word count: 452
#
# Session: 389_P
# Preview: <sync> sure okay a small town outside of cinncinatti ohio three years ago uh once a year small uh came out here for work grad school yeah trying to no
# Word count: 566
#
# Session: 390_P
# Preview: <sync> yes i'm doing pretty well um i have some stressful circumstances going on but um um right now i'm i'm engaged i'm from minnesota mhm uh thirty
# Word count: 1407
#
# Session: 391_P
# Preview: <sync> yes kind of down i don't have a boyfriend don't have any florida yep uh try to find work um about once a year mm more boring um not easy um um
# Word count: 577
#
# Session: 392_P
# Preview: <sync> yes i'm doing well uh california i like the weather i like the people i don't like the traffic uh that's primarily it sociology yep uh it's a t
# Word count: 656
#
# Session: 393_P
# Preview: <sync> yes i'm good i'm originally from los angeles california um i like the weather i like uh numerous things uh the women stuff like that traffic tr
# Word count: 705
#
# Session: 395_P
# Preview: <synch> yes i'm doing fine california here in los angeles mhm um i love being near the beach um i love the beach i love um living in a big city um and
# Word count: 1223
#
# Session: 396_P
# Preview: <synch> yes okay virginia i wanted to live somewhere different than virginia with a little bit more diversity um once a year maybe it's um it's a lot
# Word count: 1107
#
# Session: 397_P
# Preview: <sync> sure i'm good but i caught a cold morning <sniff> l_a <snort> born and raised born and raised it's home <snort> food people culture traffic uh
# Word count: 1618
#
# Session: 399_P
# Preview: <sync> yes i'm pretty good uh as far as my parents ethiopia yes um the beaches the warm weather um the diverse environment uh traffic <laughter> well
# Word count: 1140
#
# Session: 400_P
# Preview: <synch> yeah i'm fine um pacific grove california um <sigh> the wholesale opportunities and uh all the stores and anything i could ever ask for <laugh
# Word count: 1198
#
# Session: 401_P
# Preview: <sync> yes i'm okay i'm good i'm a little tired but i'm good michigan i'm from michigan um a long time ago then i left uh once twice a year cold <laug
# Word count: 1179
#
# Session: 402_P
# Preview: <sync> yes okay atlanta georgia um in two thousand and six never uh i don't like it there <laughter> oh it's completely boring and there's very little
# Word count: 1090
#
# Session: 403_P
# Preview: <sync> yes i'm doing really good i'm from granada hills california it's um the san fernando valley part of los angeles i love the weather i like the d
# Word count: 1363
#
# Session: 404_P
# Preview: <sync> yes doing good new york city well uh originally i was born here but uh spent some time back east and um moved back here and um basically sort o
# Word count: 1060
#
# Session: 405_P
# Preview: <sync> hello  yes  okay not too bad i'm from chicago south side um back in nineteen seventy eight when i was eighteen yes <y> lately not much maybe on
# Word count: 2253
#
# Session: 406_P
# Preview:  <synch> <laughter> yes i'm doing good i'm originally from southern california i like the um downtown theater district i like the beaches i i like the
# Word count: 999
#
# Session: 407_P
# Preview: <sync> yes <clears throat> i'm actually feel <f> i feel pretty good 'cause i uh i slept all day yesterday almost and i usually i'm doing something if
# Word count: 3148
#
# Session: 408_P
# Preview: <sync> yes i am i'm doing great i am originally from venezuela i was two years old yes i was um been only once i do not have family there anymore uh m
# Word count: 842
#
# Session: 409_P
# Preview: <sync> okay mm okay sure mm doing okay i'm from uh l_a yeah i like the weather i like the sports teams i like the entertainment yeah uh it's pretty mu
# Word count: 2399
#
# Session: 410_P
# Preview: <sync> yes uh i'm fine today today is my daughter's birthday california yes um the beach i love the waters the gang violence violence um i lost a lot
# Word count: 1449
#
# Session: 411_P
# Preview: <sync> sure pretty good new york uh i moved to l_a in the seventies but i yeah but i lived a lot of different places of um i guess every few years but
# Word count: 2992
#
# Session: 412_P
# Preview: <sync> yes okay originally from texas oh few weeks ago uh well i've been living in um palm springs actually so uh l_a there's a lot more to do and uh
# Word count: 857
#
# Session: 413_P
# Preview: <sync> yes i'm doing okay i'm from greenwich connecticut yes um i moved here in two thousand eight so about five years ago um i try to go back at leas
# Word count: 1692
#
# Session: 414_P
# Preview: <sync> yeah i'm okay burbank california yeah the weather of course i think everyone likes the weather um it's not too city like chicago or new york it
# Word count: 1467
#
# Session: 415_P
# Preview: <synch> yes i'm good michigan two years ago um every three months it's more homey and country than fast-paced and stuff uh the i work in the entertain
# Word count: 1197
#
# Session: 416_P
# Preview: <sync> sure i'm doing good how are you chicago yeah about twenty five years ago yeah it's been a while actually i haven't been back <laughter> i like
# Word count: 1450
#
# Session: 417_P
# Preview: <sync> yes i'm okay uh los angeles <laughter> um i don't know <laughter> um it's kinda dirty but that's to be expected from a big city um my the last
# Word count: 1205
#
# Session: 418_P
# Preview: <sync> yes i'm okay i was born in mississippi um when i was two and a half years old but actually it wasn't l_a it was santa monica yes never i was on
# Word count: 1634
#
# Session: 419_P
# Preview: <sync> yes i'm good thank you um i was born in mexico city yes um about thirty four years ago yeah <laughter> um i try to go back once a year but i ha
# Word count: 1646
#
# Session: 420_P
# Preview: <synch> mm yes i am um i'm okay chicago um back and forth over the years and traveled a little bit haven't been out there in over fifteen sixteen year
# Word count: 1085
#
# Session: 421_P
# Preview: <synch> yes that's fine i'm okay how are you <laughter> originally i'm from san francisco um originally i moved here in gosh nineteen ninety five then
# Word count: 1038
#
# Session: 422_P
# Preview: <synch> hi sure alright uh originally originally i'm from uh korea mhm uh when i was a year old yes uh almost never i've i've been to korea once uh i
# Word count: 2411
#
# Session: 423_P
# Preview: <sync> yes i'm doing well los angeles the greater los angeles area people diversity and various entertainment and activities um fickle weather traffic
# Word count: 1006
#
# Session: 424_P
# Preview: <sync> hi yes today is a wonderful day i am doing just absolutely marvelous i was born in cleveland ohio i was raised in tucson arizona and came to lo
# Word count: 2489
#
# Session: 425_P
# Preview: <synch> yes i'm okay i'm feeling a little tired and uh worried um well i'm looking for a place to live and um i don't have a job right now so things a
# Word count: 1734
#
# Session: 426_P
# Preview: <sync. yes i'm alright south l_a um the weather the women the opportunities that's about it racism police brutality injustice that's it mm no not much
# Word count: 1193
#
# Session: 427_P
# Preview: <sync> yeah sure i'm good how are you i'm from florida originally mhm where are you from oh um for work <laughter> uh i haven't been back in like a fe
# Word count: 998
#
# Session: 428_P
# Preview: <synch> <laughter> yeah i'm good how are you i'm from here <he> um from los angeles <clears throat> probably the downtown the view and it's not that i
# Word count: 980
#
# Session: 429_P
# Preview: <synch> i'm good yes i'm good iowa when or why uh two thousand one mm holidays and special family events uh it's much better there scrubbed_entry and
# Word count: 1150
#
# Session: 430_P
# Preview: <synch> yeah sure i'm fine thank you i am from los angeles well you can't beat the weather um and i just think the familiarity of home just uh makes m
# Word count: 1442
#
# Session: 431_P
# Preview: <synch> yes i'm fine um florida um about two to three months ago i haven't been back as yet um it's basically the same nice sunny weather um for a car
# Word count: 865
#
# Session: 432_P
# Preview: <synch> i'm cool fine new york yep eh about six months six months ago nicer pace uh photography job it's a good move mm uh i love the weather cool peo
# Word count: 1263
#
# Session: 433_P
# Preview: <synch> yes i'm doing good i was born in lynwood i like all the sightseeing and all the clothing and stores that they have well some things all the gr
# Word count: 923
#
# Session: 434_P
# Preview: <synch> yes i am i'm doing very good today i'm originally from chicago illinois moved out here when i was three yes i never go back family issues it d
# Word count: 2556
#
# Session: 435_P
# Preview: <synch> yes okay um santiago chile mm permanently in nineteen seventy seven mm about every three to four years it's similar uh my parents moved here v
# Word count: 1017
#
# Session: 436_P
# Preview: <synch> yes i'm doing fine uh mexico uh when i was young seven years old i've been there like uh three or four times for vacation well it's uh less st
# Word count: 1401
#
# Session: 437_P
# Preview: <synch> mm yes mm i'm doing pretty good uh i was born in los angeles mhm um i like the diversity of the city all the attractions and things that you c
# Word count: 1211
#
# Session: 438_P
# Preview: <synch> yes i'm doing pretty good i was born and raised right here in los angeles <sigh> um the weather um would be number one i also like the diverse
# Word count: 3287
#
# Session: 439_P
# Preview: <synch> yes i'm doing fine i'm from los angeles and born in los angeles yes uh you have a lot of places to go a lot of people to see a lot of things t
# Word count: 2996
#
# Session: 440_P
# Preview: <sync> yes i'm okay thank you um i was born in east los angeles and yes um the freedom to explore outdoors and with different um weather temperature <
# Word count: 1854
#
# Session: 441_P
# Preview: <sync. yes i'm doing fine thank you los angeles california the variety of people the multicultural food <laughter> and going to movies rude people sca
# Word count: 934
#
# Session: 442_P
# Preview: <sync> sure in a day uh pretty well except for drab weather originally i'm from detroit michigan yes uh back in the eighties yeah uh it's been a while
# Word count: 1544
#
# Session: 443_P
# Preview: <synch> sure good indiana um the weather i like the weather uh never um didn't wanna get back into the old groove i took some time took a long time to
# Word count: 519
#
# Session: 444_P
# Preview: <sync> yes i'm fine i'm doing very well today i feel good today uh born in indiana mhm grew up in bloomington i moved to l_a for a job working with th
# Word count: 2707
#
# Session: 445_P
# Preview: <synch> yes i feel great i am from los angeles california um the weather the opportunity and the ocean it's overcrowded overpriced and somewhat dirty
# Word count: 1007
#
# Session: 446_P
# Preview: <synch> yes i'm wonderful how are you california mhm yes the weather is one of 'em uh the food um and the way uh everything is centrally located mhm t
# Word count: 1743
#
# Session: 447_P
# Preview: <sync> yeah that's perfectly fine i'm feeling great uh it's an early morning i don't have school i'm excited <laughter> uh born and raised in los ange
# Word count: 1370
#
# Session: 448_P
# Preview: <sync> yes doing pretty good oh i was born in uh brooklyn new york i came out here when i was seven and i've been here ever since uh i don't consider
# Word count: 2486
#
# Session: 449_P
# Preview: <synch> okay yes i am i'm good thank you <laughter> originally from los angeles and my parents are from central america yes the weather um i like that
# Word count: 3066
#
# Session: 450_P
# Preview: <synch> okay i'm okay with that sure i'm doing well reasonably well i'm from santa monica california born and raised i love the ocean um i love the hi
# Word count: 1997
#
# Session: 451_P
# Preview: <sync> yes okay other than this laryngitis i have uh cleveland ohio in uh seventy nine i think it was <laughter> mhm um once a year something like tha
# Word count: 1721
#
# Session: 452_P
# Preview: <sync> mm maybe okay i'm from california it's sun there's sunshine <s> sunshine weather mhm what do you like about l_a <laughter> what do <laughter> u
# Word count: 583
#
# Session: 453_P
# Preview: <synch> yes i'm doing good uh los angeles mhm convenience convenience uh people the crowd uh traffic people not respecting <re> uh eh lack of respect
# Word count: 1492
#
# Session: 454_P
# Preview: <synch> yes great and yourself houston texas when i was very young every few years it's a little bit slower my parents brought me as a child the weath
# Word count: 673
#
# Session: 455_P
# Preview: <synch> yes very well uh ohio mhm uh finished school and came out to start my life uh not often now not really often uh because my parents have both p
# Word count: 1072
#
# Session: 456_P
# Preview: <synch> yes i'm well thank you uh boston massachusetts yes i moved to l_a about a year after graduating college in two thousand and one uh quite often
# Word count: 1630
#
# Session: 457_P
# Preview: <synch> yes spectacular this is an interesting experiment <laughter> uh i'm from middle of nowhere iowa <sigh> uh may second of two thousand seven so
# Word count: 1369
#
# Session: 458_P
# Preview: <synch> <clears throat> yes i'm doing fine thank you i'm from los angeles california yes um well the main thing i like the weather um i like the lifes
# Word count: 1297
#
# Session: 459_P
# Preview: <synch> hello yeah i'm alright a little tired uh i live in culver city um but originally i i was i grew up in venice um the beach fast drivers um the
# Word count: 1204
#
# Session: 461_P
# Preview: <synch> yes i'm okay los angeles i like the arts i like the weather i like the people hmm it's expensive smoggy a lot of traffic no i don't well i lik
# Word count: 968
#
# Session: 462_P
# Preview: <sync> yeah i'm okay uh i'm from los angeles mhm oh um the weather <laughter> the weather the weather the weather the beach the weather the beach the
# Word count: 1991
#
# Session: 463_P
# Preview: <synch> yes i am i am pretty good uh i was born in los angeles california yes um i like the fact that everything is close by um all the stores the sho
# Word count: 913
#
# Session: 464_P
# Preview: <sync> mhm um i'm doing good what about you mhm um l_a <l> los los angeles but i currently reside <res>reside in inglewood wait did i answer your ques
# Word count: 1999
#
# Session: 465_P
# Preview: <sync> yeah cool i'm hanging out you know being on an adventure chilling culver city california yeah yeah all the different microcosms and different p
# Word count: 2674
#
# Session: 466_P
# Preview: <synch> <sigh> yes uh okay <laughter> los angeles the weather um the variety of um environments the ocean you know various different environment or en
# Word count: 2406
#
# Session: 467_P
# Preview: <synch> yeah i'm okay with it uh i feel i feel pretty good little <l> little nervous because i've never done anything like this before that's why <lau
# Word count: 1232
#
# Session: 468_P
# Preview: <synch> yes i'm okay with this i'm pretty good feeling a little tired but uh feeling pretty good for the most part um redondo beach yep i like the bea
# Word count: 1849
#
# Session: 469_P
# Preview: <synch> yes i'm okay l_a mm uh there's a lot of variety um there's a lot of health-oriented stuff um there's all kinds of food to eat you can go to th
# Word count: 1674
#
# Session: 470_P
# Preview: <synch> yes i'm doing okay i'm from los angeles california the food the weather and the people mm um i don't know it's not too many things i really do
# Word count: 1414
#
# Session: 471_P
# Preview: <synch> yes i'm doing well thank you from los <l> los angeles mm sports outdoor sports mainly surfing uh snowboarding mountain biking rock climbing tr
# Word count: 1479
#
# Session: 472_P
# Preview: <synch> sure i'm well thank you southern california the weather <sigh> the uh mountains the ocean mm traffic air quality no not a lot mm time money i
# Word count: 900
#
# Session: 473_P
# Preview: <synch> yes good new jersey five years ago about <bout> once a year um there's more to do out here the weather is nice didn't take very long and the a
# Word count: 337
#
# Session: 474_P
# Preview: <synch> yes i'm good how are you uh i was born in hawaii but i grew up in colorado yeah yeah about seven <s> uh seven to eight years ago um i try to g
# Word count: 1745
#
# Session: 475_P
# Preview: <synch> yes good thank you el segundo right down the street the beach the smog i try to when i have time being away from home getting away i recently
# Word count: 720
#
# Session: 476_P
# Preview: <synch> uh yeah sure <laughter> i'm alright uh i'm in a weird test study right now uh i'm from los angeles mhm <ss> all kinds of different things to d
# Word count: 635
#
# Session: 477_P
# Preview: <synch> yes thanks i'm well thank you how are you i grew up in oklahoma mhm um i moved to l_a about five and a half years ago so i used to be on the w
# Word count: 2789
#
# Session: 478_P
# Preview: <synch> yes uh good thanks the east coast for work uh rarely i prefer it out here uh i it's um not as nice as the lifestyle out here i like the weathe
# Word count: 1293
#
# Session: 479_P
# Preview: <synch> yes okay l_a uh the smog traffic tickets high rent uh everything um like um the cost of living the smog yeah <clears throat> not anymore uh do
# Word count: 662
#
# Session: 480_P
# Preview: <synch> yes i'm fine thank you new york city yes uh seventy <s> nineteen seventy five <f> five <laughter> about <bout> once a year both urban uh big c
# Word count: 1080
#
# Session: 481_P
# Preview: <synch> yeah i am um good to moderate los angeles yeah i'm from um just a lot of different kinds of people and um eh i love the weather most of the ti
# Word count: 1996
#
# Session: 482_P
# Preview: <synch> yes i'm doing fine i was born in texas and i moved to california when i was three and grew up here in california yeah i was yes uh i've never
# Word count: 1887
#
# Session: 483_P
# Preview: <synch> sure <laughter> mm good i guess new orleans louisiana uh two thousand five i used to go back often but not much anymore uh just things happene
# Word count: 2259
#
# Session: 484_P
# Preview: <synch> <laughter> yes i'm doing well i was born in oakland um <sigh> all the different areas of the city uh the different cultures that are here the
# Word count: 1377
#
# Session: 485_P
# Preview: <synch> yes i'm not bad i'm a little tired but okay uh from saint louis missouri yep uh two months ago uh not often i think i'm out here for good now
# Word count: 705
#
# Session: 486_P
# Preview: <synch> yes i'm feel great i am from saint louis missouri born and raised yes i've been here a couple times i just recently moved back two months ago
# Word count: 768
#
# Session: 487_P
# Preview: <synch> yes i'm fine thank you detroit michigan yes i moved to l_a myself in two thousand and seven but my family came here many more years ago more l
# Word count: 1809
#
# Session: 488_P
# Preview: <synch> yes fine oh san fernando valley uh well i really like the culture i love going to museums and being able to go at night and having lots of peo
# Word count: 1413
#
# Session: 489_P
# Preview: <synch> yes i'm doing well thank you san luis obispo yes four years ago about once a month small quiet fresh air less people it's nice i went to schoo
# Word count: 491
#
# Session: 490_P
# Preview: <synch> yeah i'm doing already how are you doing northern illinois two and a half years ago haven't yet since i been here haven't had a chance to gonn
# Word count: 592
#
# Session: 491_P
# Preview: <synch> yes huh overwhelmed i have a funeral to attend tomorrow i found out from my doctor i got some health issues it is hard honey i am just putting
# Word count: 1241
#
# Session: 492_P
# Preview: <synch> yes doing pretty good thank you maryland yes eighty five yeah yeah it is a long time um not as often as i'd like um out of work so you know th
# Word count: 1259

# %%
import numpy as np
X = [text_data[s] for s in labeled_df['session']]
X_train = np.array(X)[train_mask]
X_dev   = np.array(X)[dev_mask]
X_test  = np.array(X)[test_mask]

# %%
labeled_df.head()
# Out:
#   session  audio_duration  sample_rate  transcript_word_count  num_responses  \
# 0   300_P           648.5        16000                    352             87
# 1   301_P           823.9        16000                   1475            104
# 2   302_P           758.8        16000                    614             97
# 3   303_P           985.3        16000                   1807            103
# 4   304_P           792.6        16000                    957            104
#
#   Participant_ID  PHQ_Score_0_24  PHQ8_Binary  PHQ_Score_0_10_Target split
# 0            300             2.0            0               0.833333  test
# 1            301             3.0            0               1.250000  test
# 2            302             4.0            0               1.666667  test
# 3            303             0.0            0               0.000000  test
# 4            304             6.0            0               2.500000  test

# %% [markdown]
# ## Feature Extraction: Bag-of-Words with TF-IDF
#
# We convert participant text for each session into numeric features using TF-IDF. This captures word frequency patterns for downstream ML.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=1000, ngram_range=(1,2))
X_text = vectorizer.fit_transform([text_data[s] for s in labeled_df['session']])

# %%
print(X_text[0])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 183 stored elements and shape (1, 1000)>
#   Coords	Values
#   (0, 687)	0.03960415295641828
#   (0, 388)	0.055969498841233103
#   (0, 29)	0.03436829137563162
#   (0, 448)	0.03717399246236765
#   (0, 726)	0.053427365536090246
#   (0, 865)	0.03740532639114411
#   (0, 514)	0.11083516745852068
#   (0, 578)	0.05158528332776593
#   (0, 339)	0.04578908258487871
#   (0, 832)	0.03561912664516606
#   (0, 143)	0.053427365536090246
#   (0, 781)	0.025888736575984783
#   (0, 901)	0.038355674564075445
#   (0, 783)	0.03206092438634639
#   (0, 47)	0.04065636078469891
#   (0, 13)	0.03671846728615939
#   (0, 615)	0.09977009102511784
#   (0, 496)	0.05158528332776593
#   (0, 843)	0.05884265704399747
#   (0, 144)	0.050297995635438984
#   (0, 288)	0.05158528332776593
#   (0, 973)	0.05946501336349684
#   (0, 994)	0.026733126807985803
#   (0, 889)	0.02883873725042848
#   (0, 975)	0.04262767179632739
#   :	:
#   (0, 607)	0.054335482501310046
#   (0, 540)	0.04488759114131785
#   (0, 745)	0.024162943884204074
#   (0, 18)	0.033184498118268846
#   (0, 980)	0.09977099653492828
#   (0, 829)	0.28871401096114535
#   (0, 20)	0.1554613905175398
#   (0, 103)	0.09438446541173766
#   (0, 878)	0.05041784659470107
#   (0, 688)	0.06662631022180278
#   (0, 193)	0.060277305317275494
#   (0, 812)	0.08131272156939783
#   (0, 988)	0.0752263060452374
#   (0, 925)	0.07123825329033212
#   (0, 717)	0.1767375066768794
#   (0, 402)	0.13466277342395355
#   (0, 327)	0.19987893066540832
#   (0, 432)	0.033768466611715696
#   (0, 299)	0.05928435618947506
#   (0, 244)	0.049098812026203205
#   (0, 58)	0.027167741250655023
#   (0, 563)	0.08467011150486264
#   (0, 481)	0.11104385036967128
#   (0, 850)	0.40398832027186066
#   (0, 267)	0.04488759114131785

# %%
print("TF-IDF matrix shape:", X_text.shape)
print("Sample feature vector (first 10 features):", X_text[0].toarray()[0][:10])
# Out:
# TF-IDF matrix shape: (189, 1000)
# Sample feature vector (first 10 features): [0.         0.         0.04488759 0.         0.         0.
#  0.         0.05158528 0.04147977 0.        ]

# %% [markdown]
# ## ML Baseline Modeling: Logistic Regression
#
# Train a simple logistic regression classifier and check performance on train/dev/test splits.

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
text_datas = [text_data[session] for session in labeled_df['session']]
target = labeled_df['PHQ8_Binary'].astype(int)

# TF-IDF features, as in your notebook
tfidf = TfidfVectorizer(max_features=1000)
Xtext = tfidf.fit_transform(text_datas)

train_mask = labeled_df['split'] == "train"
dev_mask = labeled_df['split'] == "dev"
test_mask = labeled_df['split'] == "test"

# Convert masks for indexing sparse matrix
X_train = Xtext[train_mask.values]
y_train = target[train_mask.values]
X_dev = Xtext[dev_mask.values]
y_dev = target[dev_mask.values]
X_test = Xtext[test_mask.values]
y_test = target[test_mask.values]

models = {
    'Logistic Regression': LogisticRegression(max_iter=200, class_weight='balanced'),
    'SVM': SVC(class_weight='balanced', probability=True),
    'Random Forest': RandomForestClassifier(class_weight='balanced', random_state=42)
}

results = {}

# %%
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)
    print(f"{name}:")
    print(classification_report(y_test, y_pred))
    print(f"Test Accuracy: {acc:.2f}")
    results[name] = (acc, cm, y_pred)

    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'{name} Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
# Out:
# Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.71      0.98      0.82       123
#            1       0.33      0.02      0.04        51
#
#     accuracy                           0.70       174
#    macro avg       0.52      0.50      0.43       174
# weighted avg       0.60      0.70      0.59       174
#
# Test Accuracy: 0.70
# SVM:
#               precision    recall  f1-score   support
#
#            0       0.71      0.99      0.83       123
#            1       0.50      0.02      0.04        51
#
#     accuracy                           0.71       174
#    macro avg       0.60      0.51      0.43       174
# weighted avg       0.65      0.71      0.60       174
#
# Test Accuracy: 0.71
# Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83       123
#            1       0.00      0.00      0.00        51
#
#     accuracy                           0.71       174
#    macro avg       0.35      0.50      0.41       174
# weighted avg       0.50      0.71      0.59       174
#
# Test Accuracy: 0.71
# C:\Users\himan\anaconda3\envs\bert-tf\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\himan\anaconda3\envs\bert-tf\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\himan\anaconda3\envs\bert-tf\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Notes and Observations: TF-IDF Baseline Model
# Model Type: The pipeline uses logistic regression (a classical linear classifier) trained on TF-IDF features extracted from transcript text.
#
# Performance: Your train accuracy is very high (1.0), while dev accuracy is lower (~0.33), and test accuracy is moderate (1.0). This indicates possible overfitting or dataset size effects—very common in small clinical datasets.
#
# Confusion Matrix: On the test set, out of 3 samples: 1 true negative (label 0 predicted as 0), and 2 true positives (label 1 predicted as 1). No false negatives or false positives. This is good, but with such a small test set, results can fluctuate with different splits.
#
# Limitations: A TF-IDF + linear classifier only captures surface-level word frequency and simple n-gram patterns. It cannot use context, semantics, emotional nuance, or longer dependencies present in real conversations or interviews.
#
# Interpretability: TF-IDF models are highly interpretable; you can easily see which words contribute most to predictions. However, they may ignore subtle cues important for depression detection.
#
# Why Use Deep Learning Models (e.g., BERT)?
# Contextual Understanding: Deep learning (especially transformers like BERT) can model word meaning in context, not just isolated frequency.
#
# Transfer Learning: Pre-trained models leverage knowledge from millions of documents—critical for tiny medical datasets like yours.
#
# Semantic and Emotional Cues: Transformers are able to capture subtle signals, patterns, and context-sensitive meanings, leading to higher accuracy and robustness.
#
# Proven Advantage: Recent research papers repeatedly show transfer learning with large language models significantly improves depression and mental health classification tasks.

# %% [markdown]
# #  BERT Transfer Learning Model and Pipeline

# %% [markdown]
# ### Motivation
# Text context matters! TF-IDF captures only surface features. BERT, via transfer learning, models deep semantic, contextual, and emotional signals crucial for detecting depression from interviews/transcripts.
#
# Modern research (e.g., AVEC 2019/2020, clinical NLP papers) consistently shows superior performance using transformer models.
#
# Extensibility: Easily swap BERT for DistilBERT, RoBERTa, etc., and compare results for publication-level analysis.

# %% [markdown]
# # BERT Architecture for Text Classification

# %% [markdown]
# ## Tokenize Data for BERT

# %%
from transformers import BertTokenizer
import numpy as np

max_len = 256  #or 512

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

def bert_encode(texts, tokenizer, max_len):
    all_input_ids = []
    all_attention_mask = []
    for text in texts:
        enc = tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=max_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='np'
        )
        all_input_ids.append(enc['input_ids'])
        all_attention_mask.append(enc['attention_mask'])
    return np.vstack(all_input_ids), np.vstack(all_attention_mask)
# Out:
# C:\Users\himan\anaconda3\envs\bert-tf\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
train_mask = labeled_df['split'] == "train"
dev_mask = labeled_df['split'] == "dev"
test_mask = labeled_df['split'] == "test"

X_train_texts = [text_data[session] for session in labeled_df['session'][train_mask.values]]
X_dev_texts   = [text_data[session] for session in labeled_df['session'][dev_mask.values]]
X_test_texts  = [text_data[session] for session in labeled_df['session'][test_mask.values]]

Xtrain_ids, Xtrain_mask = bert_encode(X_train_texts, tokenizer, max_len)
Xdev_ids, Xdev_mask     = bert_encode(X_dev_texts, tokenizer, max_len)
Xtest_ids, Xtest_mask   = bert_encode(X_test_texts, tokenizer, max_len)

# %% [markdown]
# ## Define BERT Model

# %%
from transformers import TFBertModel
import tensorflow as tf

def build_multitask_bert_regression(max_len=128, bert_model_name='bert-base-uncased', dropout_bert=0.5, dropout_fc=0.3):
    tf.keras.backend.clear_session()
    input_ids      = tf.keras.layers.Input(shape=(max_len,), dtype=tf.int32, name='input_ids')
    attention_mask = tf.keras.layers.Input(shape=(max_len,), dtype=tf.int32, name='attention_mask')

    bert = TFBertModel.from_pretrained(bert_model_name, from_pt=True)
    bert.trainable = False  # Set True to fine-tune all layers

    cls_token = bert(input_ids, attention_mask=attention_mask).last_hidden_state[:, 0, :]
    x = tf.keras.layers.Dropout(dropout_bert, name='shared_dropout')(cls_token)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(dropout_fc)(x)

    # Regression (score 0–10) head
    unscaled_output = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    score_output = tf.keras.layers.Lambda(lambda z: z * 10.0, name="score_output")(unscaled_output)
    # Binary head
    binary_output = tf.keras.layers.Dense(1, activation='sigmoid', name='binary_output')(x)

    model = tf.keras.Model(inputs=[input_ids, attention_mask], outputs=[binary_output, score_output])
    return model

model = build_multitask_bert_regression(max_len=256, dropout_bert=0.5, dropout_fc=0.3)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 256)]        0           []
#
#  attention_mask (InputLayer)    [(None, 256)]        0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  109482240   ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 256,
#                                  768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  tf.__operators__.getitem (Slic  (None, 768)         0           ['tf_bert_model[0][0]']
#  ingOpLambda)
#
#  shared_dropout (Dropout)       (None, 768)          0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 128)          98432       ['shared_dropout[0][0]']
#
#  dropout_37 (Dropout)           (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1)            129         ['dropout_37[0][0]']
#
#  binary_output (Dense)          (None, 1)            129         ['dropout_37[0][0]']
#
#  score_output (Lambda)          (None, 1)            0           ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 109,580,930
# Trainable params: 98,690
# Non-trainable params: 109,482,240
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
    loss={"binary_output": "binary_crossentropy", "score_output": "mae"},
    loss_weights={"binary_output": 0.1, "score_output": 1.0},
    metrics={"binary_output": "accuracy", "score_output": "mae"}
)

# Early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_score_output_mae', patience=18, mode='min', restore_best_weights=True)

# %%
labeled_df.head()
# Out:
#   session  audio_duration  sample_rate  transcript_word_count  num_responses  \
# 0   300_P           648.5        16000                    352             87
# 1   301_P           823.9        16000                   1475            104
# 2   302_P           758.8        16000                    614             97
# 3   303_P           985.3        16000                   1807            103
# 4   304_P           792.6        16000                    957            104
#
#   Participant_ID  PHQ_Score_0_24  PHQ8_Binary  PHQ_Score_0_10_Target split
# 0            300             2.0            0               0.833333  test
# 1            301             3.0            0               1.250000  test
# 2            302             4.0            0               1.666667  test
# 3            303             0.0            0               0.000000  test
# 4            304             6.0            0               2.500000  test

# %%
score_train = labeled_df['PHQ_Score_0_10_Target'][train_mask.values].to_numpy()
score_dev   = labeled_df['PHQ_Score_0_10_Target'][dev_mask.values].to_numpy()
score_test  = labeled_df['PHQ_Score_0_10_Target'][test_mask.values].to_numpy()

y_train = labeled_df['PHQ8_Binary'][train_mask.values].to_numpy().astype(int)
y_dev   = labeled_df['PHQ8_Binary'][dev_mask.values].to_numpy().astype(int)
y_test  = labeled_df['PHQ8_Binary'][test_mask.values].to_numpy().astype(int)

# %%
history = model.fit(
    {'input_ids': Xtrain_ids, 'attention_mask': Xtrain_mask},
    {'binary_output': y_train, 'score_output': score_train},
    validation_data=(
        {'input_ids': Xdev_ids, 'attention_mask': Xdev_mask},
        {'binary_output': y_dev, 'score_output': score_dev}
    ),
    epochs=100,
    batch_size=8,
    callbacks=[es],
    verbose=1
)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 87s 22s/step - loss: 2.8091 - binary_output_loss: 0.6827 - score_output_loss: 2.7408 - binary_output_accuracy: 0.5833 - score_output_mae: 2.7408 - val_loss: 2.7512 - val_binary_output_loss: 0.7256 - val_score_output_loss: 2.6787 - val_binary_output_accuracy: 0.3333 - val_score_output_mae: 2
- val_binary_output_accuracy: 0.3333 - val_score_output_mae: 2.9093
# Epoch 12/100
# 2/2 [==============================] - 18s 9s/step - loss: 3.6102 - binary_output_loss: 0.9116 - score_output_loss: 3.5191 - binary_output_accuracy: 0.3333 - score_output_mae: 3.5191 - val_loss: 3.0069 - val_binary_output_loss: 0.7319 - val_score_output_loss: 2.9338 - val_binary_output_accuracy: 0.3333 - val_score_output_mae: 2.9338
# Epoch 13/100
# 2/2 [==============================] - 18s 8s/step - loss: 3.2541 - binary_output_loss: 0.6381 - score_output_loss: 3.1902 - binary_output_accuracy: 0.6667 - score_output_mae: 3.1902 - val_loss: 3.0296 - val_binary_output_loss: 0.7318 - val_score_output_loss: 2.9564 - val_binary_output_accuracy: 0.3333 - val_score_output_mae: 2.9564
# Epoch 14/100
# 2/2 [==============================] - 17s 8s/step - loss: 2.9029 - binary_output_loss: 0.7443 - score_output_loss: 2.8284 - binary_output_accuracy: 0.5833 - score_output_mae: 2.8284 - val_loss: 3.0509 - val_binary_output_loss: 0.7317 - val_score_output_loss: 2.9777 - val_binary_output_accuracy: 0.3333 - val_score_output_mae: 2.9777
# Epoch 15/100
# 2/2 [==============================] - 18s 8s/step - loss: 2.8915 - binary_output_loss: 0.6775 - score_output_loss: 2.8237 - binary_output_accuracy: 0.5833 - score_output_mae: 2.8237 - val_loss: 3.0700 - val_binary_output_loss: 0.7320 - val_score_output_loss: 2.9968 - val_binary_output_accuracy: 0.3333 - val_score_output_mae: 2.9968
# Epoch 16/100
# 2/2 [==============================] - 17s 8s/step - loss: 1.9625 - binary_output_loss: 0.6103 - score_output_loss: 1.9015 - binary_output_accuracy: 0.7500 - score_output_mae: 1.9015 - val_loss: 3.0902 - val_binary_output_loss: 0.7324 - val_score_output_loss: 3.0169 - val_binary_output_accuracy: 0.3333 - val_score_output_mae: 3.0169
# Epoch 17/100
# 2/2 [==============================] - 17s 8s/step - loss: 2.1973 - binary_output_loss: 0.7314 - score_output_loss: 2.1241 - binary_output_accuracy: 0.5833 - score_output_mae: 2.1241 - val_loss: 3.1095 - val_binary_output_loss: 0.7330 - val_score_output_loss: 3.0362 - val_binary_output_accuracy: 0.3333 - val_score_output_mae: 3.0362
# Epoch 18/100
# 2/2 [==============================] - 18s 8s/step - loss: 3.3980 - binary_output_loss: 0.6495 - score_output_loss: 3.3330 - binary_output_accuracy: 0.7500 - score_output_mae: 3.3330 - val_loss: 3.1285 - val_binary_output_loss: 0.7338 - val_score_output_loss: 3.0551 - val_binary_output_accuracy: 0.3333 - val_score_output_mae: 3.0551
# Epoch 19/100
# 2/2 [==============================] - 18s 9s/step - loss: 2.3246 - binary_output_loss: 0.6226 - score_output_loss: 2.2623 - binary_output_accuracy: 0.7500 - score_output_mae: 2.2623 - val_loss: 3.1501 - val_binary_output_loss: 0.7345 - val_score_output_loss: 3.0767 - val_binary_output_accuracy: 0.3333 - val_score_output_mae: 3.0767

# %% [markdown]
# ## Evaluate and Visualize

# %%
ypred_bin, ypred_score = model.predict({'input_ids': Xtest_ids, 'attention_mask': Xtest_mask})
ytest_bin_pred = (ypred_bin > 0.5).astype(int).flatten()
ytest_score_pred = ypred_score.flatten()  # If 0-10 scaling in Lambda

# Binary metrics
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

print("Test Accuracy (Binary):", accuracy_score(y_test, ytest_bin_pred))
print(classification_report(y_test, ytest_bin_pred, target_names=["Non-Depressed", "Depressed"]))

# Confusion Matrix
cm = confusion_matrix(y_test, ytest_bin_pred)
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Test Set")
plt.show()

# Regression MAE/RMSE (0-10 score)
from sklearn.metrics import mean_absolute_error, mean_squared_error
mae = mean_absolute_error(score_test, ytest_score_pred)
rmse = np.sqrt(mean_squared_error(score_test, ytest_score_pred))
print(f"Test MAE (0-10): {mae:.3f}, Test RMSE: {rmse:.3f}")
# Out:
# 6/6 [==============================] - 99s 15s/step
# Test Accuracy (Binary): 0.7183908045977011
#                precision    recall  f1-score   support
#
# Non-Depressed       0.72      0.99      0.83       123
#     Depressed       0.75      0.06      0.11        51
#
#      accuracy                           0.72       174
#     macro avg       0.73      0.53      0.47       174
#  weighted avg       0.73      0.72      0.62       174
# Test MAE (0-10): 2.763, Test RMSE: 3.166

# %%
import matplotlib.pyplot as plt

# 1. Total Loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Total Loss')
plt.plot(history.history['val_loss'], label='Validation Total Loss')
plt.title("1. Total Loss Curve")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.grid(True)
plt.show()

# 2. Regression Metric Curve: MAE on 0–10 Score
plt.figure(figsize=(10, 6))
plt.plot(history.history['score_output_mae'], label='Train Score MAE')
plt.plot(history.history['val_score_output_mae'], label='Val Score MAE')
plt.title("2. Regression MAE Curve")
plt.ylabel("MAE (lower is better)")
plt.xlabel("Epoch")
plt.legend()
plt.grid(True)
plt.show()

# 3. Binary Accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['binary_output_accuracy'], label='Train Binary Acc')
plt.plot(history.history['val_binary_output_accuracy'], label='Val Binary Acc')
plt.title("3. Binary Classification Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # DistilBERT-Based Multitask Regression (0–10 Score + Binary)

# %%
from transformers import DistilBertTokenizer, TFDistilBertModel
import tensorflow as tf

max_len = 256
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

def bert_encode(texts, tokenizer, max_len):
    all_input_ids = []
    all_attention_mask = []
    for text in texts:
        enc = tokenizer.encode_plus(
            text if isinstance(text, str) else "",
            add_special_tokens=True,
            max_length=max_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='np'
        )
        all_input_ids.append(enc['input_ids'])
        all_attention_mask.append(enc['attention_mask'])
    return np.vstack(all_input_ids), np.vstack(all_attention_mask)

X_train_texts = [text_data[session] for session in labeled_df['session'][train_mask.values]]
X_dev_texts   = [text_data[session] for session in labeled_df['session'][dev_mask.values]]
X_test_texts  = [text_data[session] for session in labeled_df['session'][test_mask.values]]

Xtrain_ids, Xtrain_mask = bert_encode(X_train_texts, tokenizer, max_len)
Xdev_ids, Xdev_mask     = bert_encode(X_dev_texts, tokenizer, max_len)
Xtest_ids, Xtest_mask   = bert_encode(X_test_texts, tokenizer, max_len)

score_train = labeled_df['PHQ_Score_0_10Target'][train_mask.values].to_numpy()
score_dev   = labeled_df['PHQ_Score_0_10Target'][dev_mask.values].to_numpy()
score_test  = labeled_df['PHQ_Score_0_10_Target'][test_mask.values].to_numpy()

y_train = labeled_df['PHQ8_Binary'][train_mask.values].to_numpy().astype(int)
y_dev   = labeled_df['PHQ8_Binary'][dev_mask.values].to_numpy().astype(int)
y_test  = labeled_df['PHQ8_Binary'][test_mask.values].to_numpy().astype(int)

def build_multitask_distilbert_regression(max_len=256, dropout_bert=0.5, dropout_fc=0.3):
    tf.keras.backend.clear_session()
    input_ids      = tf.keras.layers.Input(shape=(max_len,), dtype=tf.int32, name='input_ids')
    attention_mask = tf.keras.layers.Input(shape=(max_len,), dtype=tf.int32, name='attention_mask')

    distilbert = TFDistilBertModel.from_pretrained('distilbert-base-uncased')
    distilbert.trainable = True  # Fine-tune whole model!

    cls_token = distilbert(input_ids, attention_mask=attention_mask).last_hidden_state[:, 0, :]
    x = tf.keras.layers.Dropout(dropout_bert, name='shared_dropout')(cls_token)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(dropout_fc)(x)

    unscaled_output = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    score_output = tf.keras.layers.Lambda(lambda z: z * 10.0, name="score_output")(unscaled_output)
    binary_output = tf.keras.layers.Dense(1, activation='sigmoid', name='binary_output')(x)

    model = tf.keras.Model(inputs=[input_ids, attention_mask], outputs=[binary_output, score_output])
    return model

model = build_multitask_distilbert_regression(max_len=256, dropout_bert=0.5, dropout_fc=0.3)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
    loss={"binary_output": "binary_crossentropy", "score_output": "mae"},
    loss_weights={"binary_output": 0.1, "score_output": 1.0},
    metrics={"binary_output": "accuracy", "score_output": "mae"}
)
es = tf.keras.callbacks.EarlyStopping(monitor='val_score_output_mae', patience=10, restore_best_weights=True)

history = model.fit(
    {'input_ids': Xtrain_ids, 'attention_mask': Xtrain_mask},
    {'binary_output': y_train, 'score_output': score_train},
    validation_data=(
        {'input_ids': Xdev_ids, 'attention_mask': Xdev_mask},
        {'binary_output': y_dev, 'score_output': score_dev}
    ),
    epochs=40,
    batch_size=8,
    callbacks=[es],
    verbose=1
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# C:\Users\himan\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\himan\.cache\huggingface\hub\models--distilbert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# C:\Users\himan\anaconda3\envs\bert-tf\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PHQ_Score_0_10Target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 32
#      29 Xdev_ids, Xdev_mask     = bert_encode(X_dev_texts, tokenizer, max_len)
#      30 Xtest_ids, Xtest_mask   = bert_encode(X_test_texts, tokenizer, max_len)
# ---> 32 score_train = labeled_df['PHQ_Score_0_10Target'][train_mask.values].to_numpy()
#      33 score_dev   = labeled_df['PHQ_Score_0_10Target'][dev_mask.values].to_numpy()
#      34 score_test  = labeled_df['PHQ_Score_0_10_Target'][test_mask.values].to_numpy()
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'PHQ_Score_0_10Target'

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, classification_report, accuracy_score
from tensorflow.keras.layers import Input, Dense, Dropout, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.losses import MeanAbsoluteError, MeanSquaredError
from transformers import TFBertModel
from copy import deepcopy

def binary_focal_loss(gamma=2., alpha=0.25):
    """Focal Loss for handling binary class imbalance."""
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        epsilon = 1e-7
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        p_t = y_true * y_pred + (1 - y_true) * (1 - y_pred)
        alpha_factor = y_true * alpha + (1 - y_true) * (1 - alpha)
        modulating_factor = tf.math.pow((1 - p_t), gamma)
        loss = -alpha_factor * modulating_factor * tf.math.log(p_t)
        return tf.reduce_mean(loss)
    return focal_loss_fixed

def build_multi_task_bert_regression(max_len=128, bert_model_name='bert-base-uncased', dropout_bert=0.5, dropout_fc=0.3):
    """Multi-Task Regression BERT model with PEFT and tunable dropout."""
    tf.keras.backend.clear_session()
    
    input_ids      = Input(shape=(max_len,), dtype=tf.int32, name='input_ids')
    attention_mask = Input(shape=(max_len,), dtype=tf.int32, name='attention_mask')

    bert = TFBertModel.from_pretrained(bert_model_name, from_pt=True) 
    bert.trainable = False # CRITICAL: Layer Freezing (PEFT)

    cls_token = bert(input_ids, attention_mask=attention_mask).last_hidden_state[:, 0, :]
    
    # Shared layers with tunable dropout
    x = Dropout(dropout_bert, name='shared_dropout')(cls_token)
    x = Dense(128, activation='relu')(x)
    x = Dropout(dropout_fc)(x)

    # 1. Regression Head (0-10 Score)
    unscaled_output = Dense(1, activation='sigmoid')(x)
    score_output = Lambda(lambda z: z * 10.0, name='score_output')(unscaled_output)

    # 2. Binary Head (Regularization)
    binary_output = Dense(1, activation='sigmoid', name='binary_output')(x)

    model = Model(inputs=[input_ids, attention_mask], outputs=[binary_output, score_output])
    return model

# %%
for i, params in enumerate(tuning_grid):
    print(f"\n--- RUN {i+1}/{len(tuning_grid)}: {params['NAME']} ---")

    # 1. Build Model
    model = build_multi_task_bert_regression(
        dropout_bert=params['D_BERT'], 
        dropout_fc=params['D_FC']
    )

    # 2. Compile Model
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=params['LR']),
        loss={
            'binary_output': binary_focal_loss(gamma=2., alpha=0.3),
            'score_output': MeanSquaredError(name='mse')
        },
        loss_weights={'binary_output': params['W_Binary'], 'score_output': 1.0},
        metrics={
            'binary_output': 'accuracy',
            'score_output': MeanAbsoluteError(name='mae')
        }
    )

    # 3. Define Early Stopping (Patience remains the primary control)
    es_callback = tf.keras.callbacks.EarlyStopping(
        monitor='val_score_output_mae', 
        mode='min',
        patience=15, 
        restore_best_weights=True
    )
    
    # 4. Train Model (Max Epochs is now controlled by patience)
    history = model.fit(
        x={'input_ids': X_train_ids, 'attention_mask': X_train_mask},
        y=y_train_mtl,
        validation_data=(
            {'input_ids': X_dev_ids, 'attention_mask': X_dev_mask},
            y_dev_mtl
        ),
        epochs=100, # Still use 100 max epochs, but ES will stop it early
        batch_size=2,
        callbacks=[es_callback],
        verbose=0 
    )

    # 5. Log Results
    min_val_mae = min(history.history['val_score_output_mae'])
    
    tuning_results.append({
        'Run': i + 1,
        'Name': params['NAME'],
        'LR': params['LR'],
        'W_Binary': params['W_Binary'],
        'D_BERT': params['D_BERT'],
        'D_FC': params['D_FC'],
        'Min_Val_MAE': min_val_mae
    })
    
    # Update Best Model Tracking
    if min_val_mae < best_val_mae:
        best_val_mae = min_val_mae
        best_params = params
        best_history = deepcopy(history.history) 
        print(f"--> NEW BEST MAE: {min_val_mae:.4f}")
# Out:
# --- RUN 1/4: BASE_STABLE ---
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# --> NEW BEST MAE: 3.0413
#
# --- RUN 2/4: HEAVY_REGULARIZATION ---
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# --> NEW BEST MAE: 2.8423
#
# --- RUN 3/4: WEIGHT_BINARY_UP ---
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# --> NEW BEST MAE: 2.7540
#
# --- RUN 4/4: OPTIMIZED_COMBO ---
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# --> NEW BEST MAE: 2.6489

# %%
results_df = pd.DataFrame(tuning_results)
print(results_df.sort_values(by='Min_Val_MAE', ascending=True))

print(f"\nBEST PARAMETERS FOUND:")
if best_params:
    print(f"Name: {best_params['NAME']}")
    print(f"Learning Rate: {best_params['LR']}")
    print(f"Binary Loss Weight: {best_params['W_Binary']}")
    print(f"Dropout BERT: {best_params['D_BERT']}")
    print(f"Dropout FC: {best_params['D_FC']}")
    print(f"Minimum Validation MAE: {best_val_mae:.4f}")

    # Plotting the Learning Curve of the BEST RUN
    if best_history:
        plt.figure(figsize=(10, 6))
        plt.plot(best_history['score_output_mae'], label='Train MAE')
        plt.plot(best_history['val_score_output_mae'], label='Validation MAE')
        plt.title(f"Best Run Regression MAE Curve ({best_params['NAME']})")
        plt.ylabel('MAE (0-10 Scale)')
        plt.xlabel('Epoch')
        plt.legend()
        plt.grid(True)
        plt.show()
# Out:
#    Run                  Name       LR  W_Binary  D_BERT  D_FC  Min_Val_MAE
# 3    4       OPTIMIZED_COMBO  0.00001       0.3     0.6   0.4     2.648935
# 2    3      WEIGHT_BINARY_UP  0.00001       0.5     0.5   0.3     2.754023
# 1    2  HEAVY_REGULARIZATION  0.00001       0.1     0.7   0.5     2.842287
# 0    1           BASE_STABLE  0.00001       0.1     0.5   0.3     3.041270
#
# BEST PARAMETERS FOUND:
# Name: OPTIMIZED_COMBO
# Learning Rate: 1e-05
# Binary Loss Weight: 0.3
# Dropout BERT: 0.6
# Dropout FC: 0.4
# Minimum Validation MAE: 2.6489

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
if not best_params:
    print("Error: Hyperparameter tuning did not run or 'best_params' is empty. Cannot proceed.")
else:
    # Use the best parameters found
    BEST_LR = best_params['LR']
    BEST_W_BINARY = best_params['W_Binary']
    BEST_D_BERT = best_params['D_BERT']
    BEST_D_FC = best_params['D_FC']

    print(f"\nRebuilding final model using Best Run parameters (LR: {BEST_LR}, Binary Weight: {BEST_W_BINARY}).")
    final_model = build_multi_task_bert_regression(
        dropout_bert=BEST_D_BERT, 
        dropout_fc=BEST_D_FC
    )

    final_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=BEST_LR),
        loss={
            'binary_output': binary_focal_loss(gamma=2., alpha=0.3),
            'score_output': MeanSquaredError(name='mse')
        },
        loss_weights={'binary_output': BEST_W_BINARY, 'score_output': 1.0},
        metrics={
            'binary_output': 'accuracy',
            'score_output': MeanAbsoluteError(name='mae')
        }
    )
    
    y_pred_bin, y_pred_score_0_10 = final_model.predict(
        {'input_ids': X_test_ids, 'attention_mask': X_test_mask}
    )
    y_test_bin_true = y_binary[test_mask]
    y_test_bin_pred = (y_pred_bin > 0.5).astype(int).flatten()

    
    # Classification Report
    print(classification_report(y_test_bin_true, y_test_bin_pred, target_names=['Non-Depressed (0)', 'Depressed (1)']))

    # Confusion Matrix
    cm = confusion_matrix(y_test_bin_true, y_test_bin_pred)
    
    plt.figure(figsize=(5, 5))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Non-Depressed', 'Depressed'])
    disp.plot(cmap=plt.cm.Blues, ax=plt.gca())
    plt.title('Confusion Matrix (Test Set - Best Tuned Model)')
    plt.show()
    y_test_score_true = y_regression_target_0_10[test_mask]
    y_test_score_pred = y_pred_score_0_10.flatten()
    mae = mean_absolute_error(y_test_score_true, y_test_score_pred)
    
    print(f"\nPRIMARY RESULT: Final Test MAE (0-10 Scale): {mae:.3f}")
# Out:
# Rebuilding final model using Best Run parameters (LR: 1e-05, Binary Weight: 0.3).
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# 1/1 [==============================] - 13s 13s/step
#                    precision    recall  f1-score   support
#
# Non-Depressed (0)       0.00      0.00      0.00         1
#     Depressed (1)       0.67      1.00      0.80         2
#
#          accuracy                           0.67         3
#         macro avg       0.33      0.50      0.40         3
#      weighted avg       0.44      0.67      0.53         3
# C:\Users\himan\anaconda3\envs\bert-tf\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\himan\anaconda3\envs\bert-tf\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\himan\anaconda3\envs\bert-tf\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# PRIMARY RESULT: Final Test MAE (0-10 Scale): 1.636

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

if 'best_history' in locals():
    history = best_history
    plt.figure(figsize=(10, 6))
    plt.plot(history['loss'], label='Train Total Loss')
    plt.plot(history['val_loss'], label='Validation Total Loss')
    plt.title('1. Total Loss Curve (Binary + Regression)')
    plt.ylabel('Loss (Weighted)')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid(True)
    plt.show()

    plt.figure(figsize=(10, 6))
    plt.plot(history['score_output_mae'], label='Train Score MAE (0-10)')
    plt.plot(history['val_score_output_mae'], label='Validation Score MAE (0-10)')
    plt.title('2. Regression Performance (MAE - Primary Metric)')
    plt.ylabel('MAE (Lower is Better)')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid(True)
    plt.show()

    plt.figure(figsize=(10, 6))
    plt.plot(history['binary_output_accuracy'], label='Train Binary Accuracy')
    plt.plot(history['val_binary_output_accuracy'], label='Validation Binary Accuracy')
    plt.title('3. Binary Classification Accuracy (Secondary Metric)')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid(True)
    plt.show()

else:
    print("Error: The 'best_history' object was not found. Please ensure the hyperparameter tuning loop was executed successfully before running this visualization block.")

# %%
import tensorflow as tf
from transformers import TFAutoModelForSequenceClassification, AutoTokenizer

model_name = "mental/mental-bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = TFAutoModelForSequenceClassification.from_pretrained(model_name)

def predict_depression_level(text):
    inputs = tokenizer(text, return_tensors="tf", truncation=True, padding=True)
    outputs = model(inputs)
    probs = tf.nn.softmax(outputs.logits, axis=-1)
    score = float(probs[0][1].numpy() * 10)  # scale to 0–10
    if score < 4: label = "Normal"
    elif score < 6: label = "Mild"
    elif score < 8: label = "Moderate"
    else: label = "Severe"
    return {"score": round(score, 2), "label": label}

sample = """
I feel tired all the time and have lost interest in things that used to make me happy.
"""
print(predict_depression_level(sample))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\utils\_http.py:407, in hf_raise_for_status(response, endpoint_name)
#     406 try:
# --> 407     response.raise_for_status()
#     408 except HTTPError as e:
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/mental/mental-bert-base-uncased/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\transformers\utils\hub.py:402, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     400 try:
#     401     # Load from URL or cache if already cached
# --> 402     resolved_file = hf_hub_download(
#     403         path_or_repo_id,
#     404         filename,
#     405         subfolder=None if len(subfolder) == 0 else subfolder,
#     406         repo_type=repo_type,
#     407         revision=revision,
#     408         cache_dir=cache_dir,
#     409         user_agent=user_agent,
#     410         force_download=force_download,
#     411         proxies=proxies,
#     412         resume_download=resume_download,
#     413         token=token,
#     414         local_files_only=local_files_only,
#     415     )
#     416 except GatedRepoError as e:
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\file_download.py:1010, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#    1009 else:
# -> 1010     return _hf_hub_download_to_cache_dir(
#    1011         # Destination
#    1012         cache_dir=cache_dir,
#    1013         # File info
#    1014         repo_id=repo_id,
#    1015         filename=filename,
#    1016         repo_type=repo_type,
#    1017         revision=revision,
#    1018         # HTTP info
#    1019         endpoint=endpoint,
#    1020         etag_timeout=etag_timeout,
#    1021         headers=hf_headers,
#    1022         proxies=proxies,
#    1023         token=token,
#    1024         # Additional options
#    1025         local_files_only=local_files_only,
#    1026         force_download=force_download,
#    1027     )
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\file_download.py:1117, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1116     # Otherwise, raise appropriate error
# -> 1117     _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1119 # From now on, etag, commit_hash, url and size are not None.
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\file_download.py:1658, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1653 elif isinstance(head_call_error, (RepositoryNotFoundError, GatedRepoError)) or (
#    1654     isinstance(head_call_error, HfHubHTTPError) and head_call_error.response.status_code == 401
#    1655 ):
#    1656     # Repo not found or gated => let's raise the actual error
#    1657     # Unauthorized => likely a token issue => let's raise the actual error
# -> 1658     raise head_call_error
#    1659 else:
#    1660     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\file_download.py:1546, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1545 try:
# -> 1546     metadata = get_hf_file_metadata(
#    1547         url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token, endpoint=endpoint
#    1548     )
#    1549 except EntryNotFoundError as http_error:
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\file_download.py:1463, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers, endpoint)
#    1462 # Retrieve metadata
# -> 1463 r = _request_wrapper(
#    1464     method="HEAD",
#    1465     url=url,
#    1466     headers=hf_headers,
#    1467     allow_redirects=False,
#    1468     follow_relative_redirects=True,
#    1469     proxies=proxies,
#    1470     timeout=timeout,
#    1471 )
#    1472 hf_raise_for_status(r)
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\file_download.py:286, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     285 if follow_relative_redirects:
# --> 286     response = _request_wrapper(
#     287         method=method,
#     288         url=url,
#     289         follow_relative_redirects=False,
#     290         **params,
#     291     )
#     293     # If redirection, we redirect only relative paths.
#     294     # This is useful in case of a renamed repository.
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\file_download.py:310, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     309 response = http_backoff(method=method, url=url, **params)
# --> 310 hf_raise_for_status(response)
#     311 return response
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\huggingface_hub\utils\_http.py:424, in hf_raise_for_status(response, endpoint_name)
#     421     message = (
#     422         f"{response.status_code} Client Error." + "\n\n" + f"Cannot access gated repo for url {response.url}."
#     423     )
# --> 424     raise _format(GatedRepoError, message, response) from e
#     426 elif error_message == "Access to this resource is disabled.":
#
# GatedRepoError: 401 Client Error. (Request ID: Root=1-68f8bd0c-51ff364b60ff4bda75ea801e;a7d71e95-7a7f-4942-af9a-85a72e570705)
#
# Cannot access gated repo for url https://huggingface.co/mental/mental-bert-base-uncased/resolve/main/config.json.
# Access to model mental/mental-bert-base-uncased is restricted. You must have access to it and be authenticated to access it. Please log in.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[75], line 5
#       2 from transformers import TFAutoModelForSequenceClassification, AutoTokenizer
#       4 model_name = "mental/mental-bert-base-uncased"
# ----> 5 tokenizer = AutoTokenizer.from_pretrained(model_name)
#       6 model = TFAutoModelForSequenceClassification.from_pretrained(model_name)
#       8 def predict_depression_level(text):
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\transformers\models\auto\tokenization_auto.py:854, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     852         config = AutoConfig.for_model(**config_dict)
#     853     else:
# --> 854         config = AutoConfig.from_pretrained(
#     855             pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     856         )
#     857 config_tokenizer_class = config.tokenizer_class
#     858 if hasattr(config, "auto_map") and "AutoTokenizer" in config.auto_map:
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\transformers\models\auto\configuration_auto.py:976, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     973 trust_remote_code = kwargs.pop("trust_remote_code", None)
#     974 code_revision = kwargs.pop("code_revision", None)
# --> 976 config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     977 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#     978 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\transformers\configuration_utils.py:632, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     630 original_kwargs = copy.deepcopy(kwargs)
#     631 # Get config dict associated with the base config file
# --> 632 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     633 if "_commit_hash" in config_dict:
#     634     original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\transformers\configuration_utils.py:689, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     685 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     687 try:
#     688     # Load from local folder or from cache or download from model Hub and cache
# --> 689     resolved_config_file = cached_file(
#     690         pretrained_model_name_or_path,
#     691         configuration_file,
#     692         cache_dir=cache_dir,
#     693         force_download=force_download,
#     694         proxies=proxies,
#     695         resume_download=resume_download,
#     696         local_files_only=local_files_only,
#     697         token=token,
#     698         user_agent=user_agent,
#     699         revision=revision,
#     700         subfolder=subfolder,
#     701         _commit_hash=commit_hash,
#     702     )
#     703     commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#     704 except EnvironmentError:
#     705     # Raise any environment error raise by `cached_file`. It will have a helpful error message adapted to
#     706     # the original exception.
#
# File ~\anaconda3\envs\bert-tf\Lib\site-packages\transformers\utils\hub.py:420, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     418     if resolved_file is not None or not _raise_exceptions_for_gated_repo:
#     419         return resolved_file
# --> 420     raise EnvironmentError(
#     421         "You are trying to access a gated repo.\nMake sure to have access to it at "
#     422         f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#     423     ) from e
#     424 except RepositoryNotFoundError as e:
#     425     raise EnvironmentError(
#     426         f"{path_or_repo_id} is not a local folder and is not a valid model identifier "
#     427         "listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to pass a token "
#     428         "having permission to this repo either by logging in with `huggingface-cli login` or by passing "
#     429         "`token=<your_token>`"
#     430     ) from e
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/mental/mental-bert-base-uncased.
# 401 Client Error. (Request ID: Root=1-68f8bd0c-51ff364b60ff4bda75ea801e;a7d71e95-7a7f-4942-af9a-85a72e570705)
#
# Cannot access gated repo for url https://huggingface.co/mental/mental-bert-base-uncased/resolve/main/config.json.
# Access to model mental/mental-bert-base-uncased is restricted. You must have access to it and be authenticated to access it. Please log in.

# %%
from huggingface_hub import login
login("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")

# %%
from huggingface_hub import whoami
print(whoami())
# Out:
# {'type': 'user', 'id': '687759af8247bd366688ea9b', 'name': 'himanjali-g', 'fullname': 'Ganapa Himanjali', 'isPro': False, 'avatarUrl': '/avatars/b4ecc60fe03cf83146317aafef697736.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'dlt_project', 'role': 'fineGrained', 'createdAt': '2025-10-22T11:24:00.075Z', 'fineGrained': {'canReadGatedRepos': False, 'global': [], 'scoped': [{'entity': {'_id': '687759af8247bd366688ea9b', 'type': 'user', 'name': 'himanjali-g'}, 'permissions': []}]}}}}

# %%
import tensorflow as tf
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
